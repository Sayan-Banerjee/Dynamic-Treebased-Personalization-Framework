# %%
try:
    import cPickle as pickle
except ImportError:  # python 3.x
    import pickle

# %%
StaticClustering = {'Attributes':
    {
        'Type': {'Adults': 'Numerical', 'Children': 'Numerical', 'LeadDays': 'Numerical', 
              'LengthOfStay': 'Numerical', 'ArrivalDateWeekDay': 'Categorical'
               },
        'Ranges': {'Adults': (1,2000), 'Children': (0, 2000), 'LeadDays': (0, 400), 
              'LengthOfStay': (1,400), 'ArrivalDateWeekDay': ['Sunday', 'Monday','Tuesday', 'Wednesday',
                                                                 'Thursday', 'Friday', 'Saturday']},
        'Default': {'Adults': 1, 'Children': 0, 'LeadDays': 10, 'LengthOfStay': 2, 
                    'ArrivalDateWeekDay': 'Friday'}
            
    },
'Clusters':{
    'Transient': [{'Adults': (1,2000), 'Children': (0, 2000), 'LeadDays': (0, 0), 
              'LengthOfStay': (1,1), 'ArrivalDateWeekDay': ['Sunday', 'Monday','Tuesday', 'Wednesday',
                                                                 'Thursday', 'Friday', 'Saturday']
               }], 
    'GeneralLongStay':[{'Adults': (1,2000), 'Children': (0, 2000), 'LeadDays': (0, 400), 
              'LengthOfStay': (8,400), 'ArrivalDateWeekDay': ['Sunday', 'Monday','Tuesday', 'Wednesday',
                                                                 'Thursday', 'Friday', 'Saturday']
               }], 
    'LeisureCoupleGetaway':[{'Adults': (2,2), 'Children': (0, 0), 'LeadDays': (2, 400), 
              'LengthOfStay': (1,2), 'ArrivalDateWeekDay': ['Friday', 'Saturday']
                }], 
    'SuddenLeisureCoupleGetaway':[{'Adults': (2,2), 'Children': (0, 0), 'LeadDays': (0, 0), 
              'LengthOfStay': (2,2), 'ArrivalDateWeekDay': ['Friday', 'Saturday']
               }, {'Adults': (2,2), 'Children': (0, 0), 'LeadDays': (1, 1), 
              'LengthOfStay': (1,2), 'ArrivalDateWeekDay': ['Friday', 'Saturday']
               }], 
    'MidWeekCoupleGetaway':[{'Adults': (2,2), 'Children': (0, 0), 'LeadDays': (1, 400), 
              'LengthOfStay': (1,2), 'ArrivalDateWeekDay': ['Sunday', 'Monday','Tuesday', 'Wednesday','Thursday']
               }, {'Adults': (2,2), 'Children': (0, 0), 'LeadDays': (0, 0), 
              'LengthOfStay': (2,2), 'ArrivalDateWeekDay': ['Sunday', 'Monday','Tuesday', 'Wednesday','Thursday']
               }], 
    'LeisureCoupleVacation':[{'Adults': (2,2), 'Children': (0, 0), 'LeadDays': (7, 400), 
              'LengthOfStay': (3,7), 'ArrivalDateWeekDay': ['Friday', 'Saturday']
                }], 
    'SuddenLeisureCoupleVacation':[{'Adults': (2,2), 'Children': (0, 0), 'LeadDays': (0, 6), 
              'LengthOfStay': (3,7), 'ArrivalDateWeekDay': ['Friday', 'Saturday']
                }],
    'MidWeekLeisureCoupleVacation':[{'Adults': (2,2), 'Children': (0, 0), 'LeadDays': (0, 400), 
              'LengthOfStay': (3,7), 'ArrivalDateWeekDay': ['Sunday', 'Monday','Tuesday', 'Wednesday','Thursday']
                }], 
    'LeisureFamilyVacation':[{'Adults': (1, 2000), 'Children': (1, 2000), 'LeadDays': (7, 400), 
              'LengthOfStay': (3,7), 'ArrivalDateWeekDay': ['Friday', 'Saturday']
                }],
    'SuddenLeisureFamilyVacation':[{'Adults': (1, 2000), 'Children': (1, 2000), 'LeadDays': (0, 6), 
              'LengthOfStay': (3,7), 'ArrivalDateWeekDay': ['Friday', 'Saturday']
                }],
    'LeisureFamilyGetaway':[{'Adults': (1, 2000), 'Children': (1, 2000), 'LeadDays': (7, 400), 
              'LengthOfStay': (1,2), 'ArrivalDateWeekDay': ['Friday', 'Saturday']
                }],
    'SuddenLeisureFamilyGetaway':[{'Adults': (1, 2000), 'Children': (1, 2000), 'LeadDays': (1, 6), 
              'LengthOfStay': (1,2), 'ArrivalDateWeekDay': ['Friday', 'Saturday']
                },{'Adults': (1, 2000), 'Children': (1, 2000), 'LeadDays': (0, 0), 
              'LengthOfStay': (2,2), 'ArrivalDateWeekDay': ['Friday', 'Saturday']
                } ],
    'MidWeekFamilyGetaway':[{'Adults': (1,2000), 'Children': (1,2000), 'LeadDays': (0, 400), 
              'LengthOfStay': (2,2), 'ArrivalDateWeekDay': ['Sunday', 'Monday','Tuesday', 'Wednesday','Thursday']
               }, {'Adults': (1,2000), 'Children': (1, 2000), 'LeadDays': (1, 400), 
              'LengthOfStay': (1,1), 'ArrivalDateWeekDay': ['Sunday', 'Monday','Tuesday', 'Wednesday','Thursday']
               }],
    'MidWeekLeisureFamilyVacation':[{'Adults': (1, 2000), 'Children': (1, 2000), 'LeadDays': (0, 400), 
              'LengthOfStay': (3,7), 'ArrivalDateWeekDay': ['Sunday', 'Monday','Tuesday', 'Wednesday','Thursday']
                }], 
    'BusinessShortStay':[{'Adults': (1, 1), 'Children': (0, 0), 'LeadDays': (1, 14), 
              'LengthOfStay': (1,2), 'ArrivalDateWeekDay': ['Monday','Tuesday', 'Wednesday','Thursday']
                }, {'Adults': (1, 1), 'Children': (0, 0), 'LeadDays': (0, 0), 
              'LengthOfStay': (2,2), 'ArrivalDateWeekDay': ['Monday','Tuesday', 'Wednesday','Thursday']
                } ],
    'PlannedBusinessShortStay':[{'Adults': (1, 1), 'Children': (0, 0), 'LeadDays': (15, 400), 
              'LengthOfStay': (1,2), 'ArrivalDateWeekDay': ['Monday','Tuesday', 'Wednesday','Thursday']
                }],
    'BusinessLongStay':[{'Adults': (1, 1), 'Children': (0, 0), 'LeadDays': (0, 21), 
              'LengthOfStay': (3,5), 'ArrivalDateWeekDay': ['Sunday', 'Monday','Tuesday', 'Wednesday','Thursday']
                }],
    'PlannedBusinessLongStay':[{'Adults': (1, 1), 'Children': (0, 0), 'LeadDays': (22, 400), 
              'LengthOfStay': (3,5), 'ArrivalDateWeekDay': ['Sunday', 'Monday','Tuesday', 'Wednesday','Thursday']
                }],
    'PersonalTimeOff':[{'Adults': (1, 1), 'Children': (0, 0), 'LeadDays': (1, 400), 
              'LengthOfStay': (1,2), 'ArrivalDateWeekDay': ['Sunday', 'Friday', 'Saturday']
                }],
    'PrivateVacation':[{'Adults': (1, 1), 'Children': (0, 0), 'LeadDays': (1, 400), 
              'LengthOfStay': (3,5), 'ArrivalDateWeekDay': ['Friday', 'Saturday']
                }, {'Adults': (1,1), 'Children': (0, 0), 'LeadDays': (1, 400), 
              'LengthOfStay': (6,7), 'ArrivalDateWeekDay': ['Sunday', 'Monday','Tuesday', 'Wednesday','Thursday', 
                                                                'Friday', 'Saturday']
               }]
    
}}

# %%
with open('./staticClustering.pickle', 'wb') as fp:
    pickle.dump(StaticClustering, fp, protocol=pickle.HIGHEST_PROTOCOL)
