# %%
import os
import sys
sys.path.append('..')

# %%
from CLTreeModules import *
from ReadWritePickleFile import *
from PruneTreeByConqueringNodes import *
from PruneTreeByMergingCentroids import *
from ClusterTree_Utility import *
from Attribute import *
from ClusterTree import *
import datetime
import math

# %% [markdown]
# ## Don't try to dig into it at the first glance. Jump to Test -1. Run it though.

# %%
def getSimpleAttributes(node, othersGroup):
    # Assert node is an instance of CLNode
    assert isinstance(node, CLNode)
    
    attributes = {}
    i = 0 
    while i<len(node.dataset.attr_names):
        attr_name = node.dataset.attr_names[i]
        uniqueValues = len(np.unique(node.dataset.getInstances(attr_name)))
        
        attributes[node.dataset.attr_names[i]]= Attribute(name=attr_name,
                                                          noOfUniqueValues = uniqueValues,
                                                          maxVal=node.dataset.max_values[i+1],
                                                          minVal = node.dataset.min_values[i+1])


        i+=1

    for key in attributes.keys():
        if attributes[key].type == 'Calculated' and re.findall("_others$", attributes[key].name)\
                and attributes[key].originalAttribute in othersGroup:
            attributes[key].setOriginalAttributeVal(othersGroup[attributes[key].originalAttribute])
        elif attributes[key].type == 'Calculated' and re.findall("_weekend$", attributes[key].name):
            attributes[key].setOriginalAttributeVal(['friday', 'saturday', 'fri', 'sat'])
        elif attributes[key].type == 'Calculated' and re.findall("_midweek$", attributes[key].name):
            attributes[key].setOriginalAttributeVal(['tuesday','wednesday', 'thursday','tue', 'wed', 'thu'])
        elif attributes[key].type == 'Calculated' and re.findall("_earlyweek$", attributes[key].name):
            attributes[key].setOriginalAttributeVal(['sunday', 'monday', 'sun', 'mon'])
        
            
    return attributes

def buildSimpleTree(CLNode, node, attributes):
    #Check if ClusterTreeNode is None and CLNode is Root
    curNode = ClusterTreeNode()
    
    if CLNode.includedInCluster:
        curNode.setParent(node)
        if CLNode.parent is None:
            curNode.setInheriatedFraction(1.0)
            if CLNode.clusterId is not None:
                curNode.setClusterId(CLNode.clusterId.strip().lower())
            else:
                curNode.setClusterId('DEFAULT')
        else:
            curNode.setInheriatedFraction(CLNode.dataset.length()/CLNode.parent.dataset.length())
            curNode.setClusterId(CLNode.clusterId.strip().lower())
        
    
    else:
        
        attribute = CLNode.attribute
        cutValue = CLNode.cutValue

        if attributes[attribute].type == 'Categorical' or attributes[attribute].type == 'Calculated':
            curNode.setAttribute(attribute=attributes[attribute].originalAttribute,
                                 attributeType=attributes[attribute].type)
            curNode.setValue(attributes[attribute].originalAttributeVal)

        else:
            curNode.setAttribute(attribute=attributes[attribute].originalAttribute, attributeType=attributes[attribute].type)
            curNode.setValue(cutValue)
            
        if CLNode.depth>0:
            curNode.setInheriatedFraction(CLNode.dataset.length()/CLNode.parent.dataset.length())
        else:
            curNode.setInheriatedFraction(0.)
        curNode.setParent(node)
        CLNodeChildren = CLNode.getChildNodes()
        left = buildSimpleTree(CLNodeChildren[0], curNode, attributes)
        curNode.setLeft(left)
        right = buildSimpleTree(CLNodeChildren[1], curNode, attributes)
        curNode.setRight(right)
        
    return curNode


def __validateMinMaxCriteria(min_y, min_split_fraction, data_length,
                             fractionOfTotalData, mergingCentroidsVsconqueringNodes, testMode):
    if testMode:
        return min_y, min_split_fraction
    
    assert fractionOfTotalData <=1.0 and fractionOfTotalData > 0.,\
        logger.error("The value of 'fractionOfTotalData' should be greater than 0 and less than or equal to 1.")
    if mergingCentroidsVsconqueringNodes:
        initial_override_min_y = 1000.0
    else:
        initial_override_min_y = 750.0
    
    if data_length > 5000.0:
        if fractionOfTotalData < 1.0:
            initial_override_min_y = math.floor(initial_override_min_y * fractionOfTotalData)
            
    else:
        if fractionOfTotalData < 1.0:
            initial_override_min_y = math.floor(initial_override_min_y * fractionOfTotalData * (data_length/5000))
    
    min_y = max(initial_override_min_y, min_y)
    
    if not mergingCentroidsVsconqueringNodes:
        min_split_fraction = min(min_split_fraction, (100/data_length))
    else:
        min_split_fraction = min(min_split_fraction, (min_y/data_length))
    
    logger.info("The min-split fraction has been set to {}".format(min_split_fraction))
    logger.info("The min_y (The minimum number of member required for a cluster) has been set to {}".format(min_y))
    
    return min_y, min_split_fraction


def __combine(monthsToTree, keys, attribute, defaultValues, curVer):
    if len(keys) == 1:
        key = keys[0]
        return monthsToTree[key]
        
    curNode = ClusterTreeNode()
    mid = math.ceil((len(keys)-1)/2)
    keys_l = keys[:mid]
    keys_r = keys[mid:]
    subtree_l = __combine(monthsToTree,keys_l, attribute, defaultValues, curVer)
    subtree_r = __combine(monthsToTree,keys_r, attribute, defaultValues, curVer)
    cutValue = ()
    for i in keys_r:
        cutValue = cutValue + i
    curNode.setAttribute(attribute=attribute, attributeType='Calculated')
    curNode.setValue(list(cutValue))
    curNode.setLeft(subtree_l.getRoot())
    subtree_l.getRoot().setParent(curNode)
    curNode.setRight(subtree_r.getRoot())
    subtree_r.getRoot().setParent(curNode)
    clusterTree = ClusterTree(curNode, defaultValues, curVer)
    return clusterTree


def __getClusterTreeFromData(data, categoricalAttributes, mergingCentroidsVsconqueringNodes, balancedPrune,
                             min_y, min_split_fraction, conquerDataColumns, prefixString, defaultValues, prevVer):
    
    if categoricalAttributes is not None:
        othersGroup, data = getOthersGoup(data, categoricalAttributes, min_split_fraction)
    else:
        othersGroup = None

    data.reset_index(inplace=True, drop=True)
    if not mergingCentroidsVsconqueringNodes:
        if conquerDataColumns is not None:
            conquerData = pd.DataFrame(data[conquerDataColumns].copy(deep=True))
            data = data[list(set(data.columns)-set(conquerDataColumns))].copy(deep=True)
            divideData = data.copy(deep=True)
        else:
            eps = 0.00001
            divideData = data.copy(deep=True)
            conquerData = data.copy(deep=True)
            for col in conquerData.columns:
                mn = min(conquerData[col])
                mx = max(conquerData[col])
                conquerData[col] = (conquerData[col] - mn)/(mx - mn + eps)
                
    d_var = dict(data.var())
    d_cols = sorted(d_var, key=d_var.get, reverse=True)
    data = data[d_cols]


    r = DataFrameReader(data)
    data = r.read()
    min_split = np.ceil(data.length() * min_split_fraction)
    cltree = CLTree(data, min_split)
    cltree.buildTree()
    min_y = max(min_y, min_split)
    data_length = data.length()

    if mergingCentroidsVsconqueringNodes:
        result, baseVer = pruneByGridSearch_Centroid(cltree, min_y, data_length, prefixString, balancedPrune)
    else:
        gradientTolerance = 0.05
        result, baseVer = pruneByGridSearch(cltree, min_y, prefixString, gradientTolerance, conquerData, divideData)

    utc_now = datetime.datetime.now()
    deltaVer = math.ceil(float((utc_now - datetime.datetime(1970, 1, 1)).total_seconds()))
    deltaVer = float("." + str(deltaVer))
    
    if math.floor(prevVer) == math.floor(baseVer):
        curVer = baseVer + deltaVer
    else:
        curVer = baseVer
    
    attributes = getSimpleAttributes(node=cltree.root, othersGroup=othersGroup)
    simpleTreeRoot = buildSimpleTree(CLNode=cltree.root, node = None, attributes=attributes)            
    clusterTree = ClusterTree(simpleTreeRoot, defaultValues, curVer)
    return clusterTree

# %% [markdown]
# ## Test - 1

# %% [markdown]
# **Test of pruning on demo data with min_y = 20[soft bound, hard bound = (20 - 20*0.1)].
# Mechanism used here, is "MergingCentroids".**

# %%
import pandas as pd
df = pd.read_csv('ToDemotestData.csv', delimiter=';')
df.drop(columns='Unnamed: 0', inplace=True)

# %%
df.head()
# Out:
#    People  avgSpend
# 0       5      27.0
# 1       8      47.0
# 2       4      65.0
# 3       3      44.0
# 4       8      55.0

# %%
df.columns = ['people', 'avgspend']
defaultValues = {'people': 2.0, 'avgspend': 35.0}

# %%
clusterTree = __getClusterTreeFromData(df, categoricalAttributes = None, mergingCentroidsVsconqueringNodes=True,
                                       balancedPrune=False, min_y=20, min_split_fraction=0.20,
                                       conquerDataColumns=None,
                                       prefixString='DEMO_DATA_', defaultValues=defaultValues, prevVer=0.0)

attributes, clusters = getAttributesAndClusters(clusterTree)
writePickleFile(path='./DEMO_DATA_ClusterTree_MC_P.pickle', data=clusterTree)
# Out:
# 2019-11-26 16:59:00,758 - 4609271232 - INFO - read 100
# 2019-11-26 16:59:00,758 - 4609271232 - INFO - attribute names: [('id', <class 'float'>), ('avgspend', <class 'float'>), ('people', <class 'float'>)]
# 2019-11-26 16:59:00,759 - 4609271232 - INFO - This is the starting point!
# 2019-11-26 16:59:00,770 - 4609271232 - INFO - At this level the best cut is found on Attribute: people, at: 8.0
# 2019-11-26 16:59:00,771 - 4609271232 - INFO - At previous level(0), the cut happened on Attribute:people, Value: 8.0
# 2019-11-26 16:59:00,783 - 4609271232 - INFO - At this level the best cut is found on Attribute: avgspend, at: 78.0
# 2019-11-26 16:59:00,784 - 4609271232 - INFO - At previous level(1), the cut happened on Attribute:avgspend, Value: 78.0
# 2019-11-26 16:59:00,796 - 4609271232 - INFO - At this level the best cut is found on Attribute: people, at: 7.0
# 2019-11-26 16:59:00,797 - 4609271232 - INFO - At previous level(2), the cut happened on Attribute:people, Value: 7.0
# 2019-11-26 16:59:00,809 - 4609271232 - INFO - At this level the best cut is found on Attribute: people, at: 6.0
# 2019-11-26 16:59:00,810 - 4609271232 - INFO - At previous level(3), the cut happened on Attribute:people, Value: 6.0
# 2019-11-26 16:59:00,820 - 4609271232 - INFO - At this level the best cut is found on Attribute: people, at: 1.0
# 2019-11-26 16:59:00,821 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 16:59:00,822 - 4609271232 - INFO - Level: 5, Datapoints:
# Data: 4
# ['avgspend', 'people']
#  Max :[95. 52.  1.]
#  Min :[ 5. 40.  1.]
#
# --------
#
# 2019-11-26 16:59:00,822 - 4609271232 - INFO - At previous level(4), the cut happened on Attribute:people, Value: 1.0
# 2019-11-26 16:59:00,831 - 4609271232 - INFO - At this level the best cut is found on Attribute: avgspend, at: 23.0
# 2019-11-26 16:59:00,832 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 16:59:00,833 - 4609271232 - INFO - Level: 6, Datapoints:
# Data: 2
# ['avgspend', 'people']
#  Max :[82. 23.  5.]
#  Min :[28. 21.  4.]
#
# --------
#
# 2019-11-26 16:59:00,833 - 4609271232 - INFO - At previous level(5), the cut happened on Attribute:avgspend, Value: 23.0
# 2019-11-26 16:59:00,842 - 4609271232 - INFO - At this level the best cut is found on Attribute: avgspend, at: 74.0
# 2019-11-26 16:59:00,843 - 4609271232 - INFO - At previous level(6), the cut happened on Attribute:avgspend, Value: 74.0
# 2019-11-26 16:59:00,854 - 4609271232 - INFO - At this level the best cut is found on Attribute: avgspend, at: 69.0
# 2019-11-26 16:59:00,854 - 4609271232 - INFO - At previous level(7), the cut happened on Attribute:avgspend, Value: 69.0
# 2019-11-26 16:59:00,863 - 4609271232 - INFO - At this level the best cut is found on Attribute: avgspend, at: 28.0
# 2019-11-26 16:59:00,863 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 16:59:00,864 - 4609271232 - INFO - Level: 9, Datapoints:
# Data: 2
# ['avgspend', 'people']
#  Max :[55. 28.  6.]
#  Min :[ 0. 27.  5.]
#
# --------
#
# 2019-11-26 16:59:00,865 - 4609271232 - INFO - At previous level(8), the cut happened on Attribute:avgspend, Value: 28.0
# 2019-11-26 16:59:00,872 - 4609271232 - INFO - At this level the best cut is found on Attribute: avgspend, at: 65.0
# 2019-11-26 16:59:00,872 - 4609271232 - INFO - At previous level(9), the cut happened on Attribute:avgspend, Value: 65.0
# 2019-11-26 16:59:00,878 - 4609271232 - INFO - At this level the best cut is found on Attribute: avgspend, at: 33.0
# 2019-11-26 16:59:00,879 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 16:59:00,880 - 4609271232 - INFO - Level: 11, Datapoints:
# Data: 3
# ['avgspend', 'people']
#  Max :[91. 33.  6.]
#  Min :[12. 30.  3.]
#
# --------
#
# 2019-11-26 16:59:00,880 - 4609271232 - INFO - At previous level(10), the cut happened on Attribute:avgspend, Value: 33.0
# 2019-11-26 16:59:00,886 - 4609271232 - INFO - At this level the best cut is found on Attribute: avgspend, at: 57.0
# 2019-11-26 16:59:00,887 - 4609271232 - INFO - At previous level(11), the cut happened on Attribute:avgspend, Value: 57.0
# 2019-11-26 16:59:00,891 - 4609271232 - INFO - At this level the best cut is found on Attribute: avgspend, at: 56.0
# 2019-11-26 16:59:00,892 - 4609271232 - INFO - At previous level(12), the cut happened on Attribute:avgspend, Value: 56.0
# 2019-11-26 16:59:00,897 - 4609271232 - INFO - At this level the best cut is found on Attribute: avgspend, at: 52.0
# 2019-11-26 16:59:00,898 - 4609271232 - INFO - At previous level(13), the cut happened on Attribute:avgspend, Value: 52.0
# 2019-11-26 16:59:00,902 - 4609271232 - INFO - At this level the best cut is found on Attribute: people, at: 5.0
# 2019-11-26 16:59:00,903 - 4609271232 - INFO - At previous level(14), the cut happened on Attribute:people, Value: 5.0
# 2019-11-26 16:59:00,906 - 4609271232 - INFO - At this level the best cut is found on Attribute: people, at: 4.0
# 2019-11-26 16:59:00,907 - 4609271232 - INFO - At previous level(15), the cut happened on Attribute:people, Value: 4.0
# 2019-11-26 16:59:00,909 - 4609271232 - INFO - At this level the best cut is found on Attribute: people, at: 3.0
# 2019-11-26 16:59:00,910 - 4609271232 - INFO - At previous level(16), the cut happened on Attribute:people, Value: 3.0
# 2019-11-26 16:59:00,914 - 4609271232 - INFO - At this level the best cut is found on Attribute: avgspend, at: 46.0
# 2019-11-26 16:59:00,915 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 16:59:00,915 - 4609271232 - INFO - Level: 18, Datapoints:
# Data: 18
# ['avgspend', 'people']
#  Max :[88. 46.  3.]
#  Min :[ 3. 36.  2.]
#
# --------
#
# 2019-11-26 16:59:00,916 - 4609271232 - INFO - Inadequate data points to create further split on right child!
# 2019-11-26 16:59:00,916 - 4609271232 - INFO - Level: 18, Datapoints:
# Data: 9
# ['avgspend', 'people']
#  Max :[98. 52.  3.]
#  Min :[11. 48.  2.]
#
# --------
#
# 2019-11-26 16:59:00,917 - 4609271232 - INFO - Inadequate data points to create further split on right child!
# 2019-11-26 16:59:00,917 - 4609271232 - INFO - Level: 17, Datapoints:
# Data: 5
# ['avgspend', 'people']
#  Max :[73. 45.  4.]
#  Min :[10. 34.  4.]
#
# --------
#
# 2019-11-26 16:59:00,918 - 4609271232 - INFO - Inadequate data points to create further split on right child!
# 2019-11-26 16:59:00,918 - 4609271232 - INFO - Level: 16, Datapoints:
# Data: 5
# ['avgspend', 'people']
#  Max :[97. 48.  5.]
#  Min :[ 7. 37.  5.]
#
# --------
#
# 2019-11-26 16:59:00,919 - 4609271232 - INFO - Inadequate data points to create further split on right child!
# 2019-11-26 16:59:00,919 - 4609271232 - INFO - Level: 15, Datapoints:
# Data: 4
# ['avgspend', 'people']
#  Max :[85. 49.  6.]
#  Min :[18. 42.  6.]
#
# --------
#
# 2019-11-26 16:59:00,920 - 4609271232 - INFO - Inadequate data points to create further split on right child!
# 2019-11-26 16:59:00,920 - 4609271232 - INFO - Level: 14, Datapoints:
# Data: 10
# ['avgspend', 'people']
#  Max :[90. 56.  6.]
#  Min :[ 8. 54.  2.]
#
# --------
#
# 2019-11-26 16:59:00,921 - 4609271232 - INFO - Inadequate data points to create further split on right child!
# 2019-11-26 16:59:00,921 - 4609271232 - INFO - Level: 13, Datapoints:
# Data: 1
# ['avgspend', 'people']
#  Max :[75. 57.  2.]
#  Min :[75. 57.  2.]
#
# --------
#
# 2019-11-26 16:59:00,921 - 4609271232 - INFO - Inadequate data points to create further split on right child!
# 2019-11-26 16:59:00,922 - 4609271232 - INFO - Level: 12, Datapoints:
# Data: 9
# ['avgspend', 'people']
#  Max :[99. 65.  6.]
#  Min :[ 2. 58.  2.]
#
# --------
#
# 2019-11-26 16:59:00,923 - 4609271232 - INFO - Inadequate data points to create further split on right child!
# 2019-11-26 16:59:00,923 - 4609271232 - INFO - Level: 10, Datapoints:
# Data: 4
# ['avgspend', 'people']
#  Max :[92. 69.  6.]
#  Min :[20. 66.  3.]
#
# --------
#
# 2019-11-26 16:59:00,923 - 4609271232 - INFO - Inadequate data points to create further split on right child!
# 2019-11-26 16:59:00,924 - 4609271232 - INFO - Level: 8, Datapoints:
# Data: 5
# ['avgspend', 'people']
#  Max :[93. 74.  6.]
#  Min :[32. 71.  2.]
#
# --------
#
# 2019-11-26 16:59:00,924 - 4609271232 - INFO - Inadequate data points to create further split on right child!
# 2019-11-26 16:59:00,925 - 4609271232 - INFO - Level: 7, Datapoints:
# Data: 1
# ['avgspend', 'people']
#  Max :[53. 78.  6.]
#  Min :[53. 78.  6.]
#
# --------
# 2019-11-26 16:59:00,925 - 4609271232 - INFO - Inadequate data points to create further split on right child!
# 2019-11-26 16:59:00,926 - 4609271232 - INFO - Level: 4, Datapoints:
# Data: 4
# ['avgspend', 'people']
#  Max :[96. 61.  7.]
#  Min :[ 9. 26.  7.]
#
# --------
#
# 2019-11-26 16:59:00,927 - 4609271232 - INFO - Inadequate data points to create further split on right child!
# 2019-11-26 16:59:00,927 - 4609271232 - INFO - Level: 3, Datapoints:
# Data: 7
# ['avgspend', 'people']
#  Max :[76. 63.  8.]
#  Min :[ 1. 40.  8.]
#
# --------
#
# 2019-11-26 16:59:00,928 - 4609271232 - INFO - Inadequate data points to create further split on right child!
# 2019-11-26 16:59:00,928 - 4609271232 - INFO - Level: 2, Datapoints:
# Data: 4
# ['avgspend', 'people']
#  Max :[72. 91.  8.]
#  Min :[23. 82.  2.]
#
# --------
#
# 2019-11-26 16:59:00,929 - 4609271232 - INFO - Inadequate data points to create further split on right child!
# 2019-11-26 16:59:00,929 - 4609271232 - INFO - Level: 1, Datapoints:
# Data: 3
# ['avgspend', 'people']
#  Max :[86. 58. 10.]
#  Min :[49. 24.  9.]
#
# --------
#
# 2019-11-26 16:59:00,930 - 4609271232 - INFO - Printing MergeList: []
# 2019-11-26 16:59:00,931 - 4609271232 - INFO - Printing Touching Nodes: {}
# 2019-11-26 16:59:00,934 - 4609271232 - INFO - Min_Y: 18.0, Scenario: dict_values([32, 18, 33, 17]),  #Clusters: 3.99, argminMetric: 0.21759035667430235
# 2019-11-26 16:59:00,935 - 4609271232 - INFO - Min_Y: 18.0, Scenario: dict_values([32, 33, 35]),  #Clusters: 3, argminMetric: 0.28066307974162497
# 2019-11-26 16:59:00,936 - 4609271232 - INFO - Min_Y: 18.0, Scenario: dict_values([35, 65]),  #Clusters: 2, argminMetric: 0.5168240677604882
# 2019-11-26 16:59:00,937 - 4609271232 - INFO - Searching for 'min_y'. Current 'min_y' = 18.0, 'result' =
# {'intra-cluster-distance': 0.021426645782930735, 'inter-cluster-distance': 0.09847235621186393, 'purity': 0.21759046505225452, 'varPurity': 1.5510097156491267, 'mean-members': 25.0, 'data-points': {'DEMO_DATA__cluster_0': 32, 'DEMO_DATA__cluster_1': 18, 'DEMO_DATA__cluster_2': 33, 'DEMO_DATA__cluster_DEFAULT': 17}, 'argminMetric': 0.21759046505225452}
# 2019-11-26 16:59:00,938 - 4609271232 - INFO - Printing MergeList: []
# 2019-11-26 16:59:00,938 - 4609271232 - INFO - Printing Touching Nodes: {}
# 2019-11-26 16:59:00,940 - 4609271232 - INFO - Min_Y: 19.0, Scenario: dict_values([32, 33, 35]),  #Clusters: 3, argminMetric: 0.28066307974162497
# 2019-11-26 16:59:00,942 - 4609271232 - INFO - Min_Y: 19.0, Scenario: dict_values([35, 65]),  #Clusters: 2, argminMetric: 0.5168240677604882
# 2019-11-26 16:59:00,943 - 4609271232 - INFO - Searching for 'min_y'. Current 'min_y' = 19.0, 'result' =
# {'intra-cluster-distance': 0.01805355190830479, 'inter-cluster-distance': 0.06432460902049568, 'purity': 0.2806632202389665, 'varPurity': 1.0639656446451762, 'mean-members': 33.333333333333336, 'data-points': {'DEMO_DATA__cluster_0': 32, 'DEMO_DATA__cluster_1': 33, 'DEMO_DATA__cluster_2': 35}, 'argminMetric': 0.2806632202389665}
# 2019-11-26 16:59:00,944 - 4609271232 - INFO - Printing MergeList: []
# 2019-11-26 16:59:00,944 - 4609271232 - INFO - Printing Touching Nodes: {}
# 2019-11-26 16:59:00,946 - 4609271232 - INFO - Min_Y: 19.0, Scenario: dict_values([32, 33, 35]),  #Clusters: 3, argminMetric: 0.28066307974162497
# 2019-11-26 16:59:00,947 - 4609271232 - INFO - Min_Y: 19.0, Scenario: dict_values([35, 65]),  #Clusters: 2, argminMetric: 0.5168240677604882
# 2019-11-26 16:59:00,948 - 4609271232 - INFO - Searching for 'min_y'. Current 'min_y' = 19.0, 'result' =
# {'intra-cluster-distance': 0.01805355190830479, 'inter-cluster-distance': 0.06432460902049568, 'purity': 0.2806632202389665, 'varPurity': 1.0639656446451762, 'mean-members': 33.333333333333336, 'data-points': {'DEMO_DATA__cluster_0': 32, 'DEMO_DATA__cluster_1': 33, 'DEMO_DATA__cluster_2': 35}, 'argminMetric': 0.2806632202389665}
# 2019-11-26 16:59:00,949 - 4609271232 - INFO - Printing MergeList: []
# 2019-11-26 16:59:00,949 - 4609271232 - INFO - Printing Touching Nodes: {}
# 2019-11-26 16:59:00,952 - 4609271232 - INFO - Min_Y: 19.0, Scenario: dict_values([32, 33, 35]),  #Clusters: 3, argminMetric: 0.28066307974162497
# 2019-11-26 16:59:00,953 - 4609271232 - INFO - Min_Y: 19.0, Scenario: dict_values([35, 65]),  #Clusters: 2, argminMetric: 0.5168240677604882
# 2019-11-26 16:59:00,954 - 4609271232 - INFO - Searching for 'min_y'. Current 'min_y' = 19.0, 'result' =
# {'intra-cluster-distance': 0.01805355190830479, 'inter-cluster-distance': 0.06432460902049568, 'purity': 0.2806632202389665, 'varPurity': 1.0639656446451762, 'mean-members': 33.333333333333336, 'data-points': {'DEMO_DATA__cluster_0': 32, 'DEMO_DATA__cluster_1': 33, 'DEMO_DATA__cluster_2': 35}, 'argminMetric': 0.2806632202389665}
# 2019-11-26 16:59:00,955 - 4609271232 - INFO - Printing MergeList: []
# 2019-11-26 16:59:00,955 - 4609271232 - INFO - Printing Touching Nodes: {}
# 2019-11-26 16:59:00,958 - 4609271232 - INFO - Min_Y: 19.0, Scenario: dict_values([32, 33, 35]),  #Clusters: 3, argminMetric: 0.28066307974162497
# 2019-11-26 16:59:00,959 - 4609271232 - INFO - Min_Y: 19.0, Scenario: dict_values([35, 65]),  #Clusters: 2, argminMetric: 0.5168240677604882
# 2019-11-26 16:59:00,960 - 4609271232 - INFO - Searching for 'min_y'. Current 'min_y' = 19.0, 'result' =
# {'intra-cluster-distance': 0.01805355190830479, 'inter-cluster-distance': 0.06432460902049568, 'purity': 0.2806632202389665, 'varPurity': 1.0639656446451762, 'mean-members': 33.333333333333336, 'data-points': {'DEMO_DATA__cluster_0': 32, 'DEMO_DATA__cluster_1': 33, 'DEMO_DATA__cluster_2': 35}, 'argminMetric': 0.2806632202389665}
# 2019-11-26 16:59:00,961 - 4609271232 - INFO - Printing MergeList: []
# 2019-11-26 16:59:00,962 - 4609271232 - INFO - Printing Touching Nodes: {}
# 2019-11-26 16:59:00,964 - 4609271232 - INFO - Min_Y: 20.0, Scenario: dict_values([32, 33, 35]),  #Clusters: 3, argminMetric: 0.28066307974162497
# 2019-11-26 16:59:00,966 - 4609271232 - INFO - Min_Y: 20.0, Scenario: dict_values([35, 65]),  #Clusters: 2, argminMetric: 0.5168240677604882
# 2019-11-26 16:59:00,967 - 4609271232 - INFO - Searching for 'min_y'. Current 'min_y' = 20.0, 'result' =
# {'intra-cluster-distance': 0.01805355190830479, 'inter-cluster-distance': 0.06432460902049568, 'purity': 0.2806632202389665, 'varPurity': 1.0639656446451762, 'mean-members': 33.333333333333336, 'data-points': {'DEMO_DATA__cluster_0': 32, 'DEMO_DATA__cluster_1': 33, 'DEMO_DATA__cluster_2': 35}, 'argminMetric': 0.2806632202389665}
# 2019-11-26 16:59:00,967 - 4609271232 - INFO - Printing MergeList: []
# 2019-11-26 16:59:00,968 - 4609271232 - INFO - Printing Touching Nodes: {}
# 2019-11-26 16:59:00,970 - 4609271232 - INFO - Min_Y: 20.0, Scenario: dict_values([32, 33, 35]),  #Clusters: 3, argminMetric: 0.28066307974162497
# 2019-11-26 16:59:00,971 - 4609271232 - INFO - Min_Y: 20.0, Scenario: dict_values([35, 65]),  #Clusters: 2, argminMetric: 0.5168240677604882
# 2019-11-26 16:59:00,972 - 4609271232 - INFO - Searching for 'min_y'. Current 'min_y' = 20.0, 'result' =
# {'intra-cluster-distance': 0.01805355190830479, 'inter-cluster-distance': 0.06432460902049568, 'purity': 0.2806632202389665, 'varPurity': 1.0639656446451762, 'mean-members': 33.333333333333336, 'data-points': {'DEMO_DATA__cluster_0': 32, 'DEMO_DATA__cluster_1': 33, 'DEMO_DATA__cluster_2': 35}, 'argminMetric': 0.2806632202389665}
# 2019-11-26 16:59:00,973 - 4609271232 - INFO - Printing MergeList: []
# 2019-11-26 16:59:00,973 - 4609271232 - INFO - Printing Touching Nodes: {}
# 2019-11-26 16:59:00,975 - 4609271232 - INFO - Min_Y: 20.0, Scenario: dict_values([32, 33, 35]),  #Clusters: 3, argminMetric: 0.28066307974162497
# 2019-11-26 16:59:00,976 - 4609271232 - INFO - Min_Y: 20.0, Scenario: dict_values([35, 65]),  #Clusters: 2, argminMetric: 0.5168240677604882
# 2019-11-26 16:59:00,977 - 4609271232 - INFO - Searching for 'min_y'. Current 'min_y' = 20.0, 'result' =
# {'intra-cluster-distance': 0.01805355190830479, 'inter-cluster-distance': 0.06432460902049568, 'purity': 0.2806632202389665, 'varPurity': 1.0639656446451762, 'mean-members': 33.333333333333336, 'data-points': {'DEMO_DATA__cluster_0': 32, 'DEMO_DATA__cluster_1': 33, 'DEMO_DATA__cluster_2': 35}, 'argminMetric': 0.2806632202389665}
# 2019-11-26 16:59:00,978 - 4609271232 - INFO - Printing MergeList: []
# 2019-11-26 16:59:00,979 - 4609271232 - INFO - Printing Touching Nodes: {}
# 2019-11-26 16:59:00,982 - 4609271232 - INFO - Min_Y: 20.0, Scenario: dict_values([32, 33, 35]),  #Clusters: 3, argminMetric: 0.28066307974162497
# 2019-11-26 16:59:00,983 - 4609271232 - INFO - Min_Y: 20.0, Scenario: dict_values([35, 65]),  #Clusters: 2, argminMetric: 0.5168240677604882
# 2019-11-26 16:59:00,985 - 4609271232 - INFO - Searching for 'min_y'. Current 'min_y' = 20.0, 'result' =
# {'intra-cluster-distance': 0.01805355190830479, 'inter-cluster-distance': 0.06432460902049568, 'purity': 0.2806632202389665, 'varPurity': 1.0639656446451762, 'mean-members': 33.333333333333336, 'data-points': {'DEMO_DATA__cluster_0': 32, 'DEMO_DATA__cluster_1': 33, 'DEMO_DATA__cluster_2': 35}, 'argminMetric': 0.2806632202389665}
# 2019-11-26 16:59:00,986 - 4609271232 - INFO - Printing MergeList: []
# 2019-11-26 16:59:00,987 - 4609271232 - INFO - Printing Touching Nodes: {}
# 2019-11-26 16:59:00,989 - 4609271232 - INFO - Min_Y: 20.0, Scenario: dict_values([32, 33, 35]),  #Clusters: 3, argminMetric: 0.28066307974162497
# 2019-11-26 16:59:00,990 - 4609271232 - INFO - Min_Y: 20.0, Scenario: dict_values([35, 65]),  #Clusters: 2, argminMetric: 0.5168240677604882
# 2019-11-26 16:59:00,992 - 4609271232 - INFO - Searching for 'min_y'. Current 'min_y' = 20.0, 'result' =
# {'intra-cluster-distance': 0.01805355190830479, 'inter-cluster-distance': 0.06432460902049568, 'purity': 0.2806632202389665, 'varPurity': 1.0639656446451762, 'mean-members': 33.333333333333336, 'data-points': {'DEMO_DATA__cluster_0': 32, 'DEMO_DATA__cluster_1': 33, 'DEMO_DATA__cluster_2': 35}, 'argminMetric': 0.2806632202389665}
# 2019-11-26 16:59:00,992 - 4609271232 - INFO - balancedPrune: False, All argminMetric: {18.0: 0.21759046505225452, 19.0: 0.2806632202389665, 20.0: 0.2806632202389665}
# 2019-11-26 16:59:00,992 - 4609271232 - INFO - All intermediate stats, generated during grid search: {18.0: {'intra-cluster-distance': 0.021426645782930735, 'inter-cluster-distance': 0.09847235621186393, 'purity': 0.21759046505225452, 'varPurity': 1.5510097156491267, 'mean-members': 25.0, 'data-points': {'DEMO_DATA__cluster_0': 32, 'DEMO_DATA__cluster_1': 18, 'DEMO_DATA__cluster_2': 33, 'DEMO_DATA__cluster_DEFAULT': 17}, 'argminMetric': 0.21759046505225452}, 19.0: {'intra-cluster-distance': 0.01805355190830479, 'inter-cluster-distance': 0.06432460902049568, 'purity': 0.2806632202389665, 'varPurity': 1.0639656446451762, 'mean-members': 33.333333333333336, 'data-points': {'DEMO_DATA__cluster_0': 32, 'DEMO_DATA__cluster_1': 33, 'DEMO_DATA__cluster_2': 35}, 'argminMetric': 0.2806632202389665}, 20.0: {'intra-cluster-distance': 0.01805355190830479, 'inter-cluster-distance': 0.06432460902049568, 'purity': 0.2806632202389665, 'varPurity': 1.0639656446451762, 'mean-members': 33.333333333333336, 'data-points': {'DEMO_DATA__cluster_0': 32, 'DEMO_DATA__cluster_1': 33, 'DEMO_DATA__cluster_2': 35}, 'argminMetric': 0.2806632202389665}}
# 2019-11-26 16:59:00,993 - 4609271232 - INFO - Printing MergeList: []
# 2019-11-26 16:59:00,993 - 4609271232 - INFO - Printing Touching Nodes: {}
# 2019-11-26 16:59:00,995 - 4609271232 - INFO - Min_Y: 18.0, Scenario: dict_values([32, 18, 33, 17]),  #Clusters: 3.99, argminMetric: 0.21759035667430235
# 2019-11-26 16:59:00,997 - 4609271232 - INFO - Min_Y: 18.0, Scenario: dict_values([32, 33, 35]),  #Clusters: 3, argminMetric: 0.28066307974162497
# 2019-11-26 16:59:00,998 - 4609271232 - INFO - Min_Y: 18.0, Scenario: dict_values([35, 65]),  #Clusters: 2, argminMetric: 0.5168240677604882
# 2019-11-26 16:59:01,000 - 4609271232 - INFO - Search Mode: False.            Note: The underlying Tree structure got modified in the process of pruning to make the search space optimized!            'min_y' = 18.0, 'result' =
# {'intra-cluster-distance': 0.021426635203383452, 'inter-cluster-distance': 0.0984723562117676, 'purity': 0.2175903576157441, 'varPurity': 1.5510093795261746, 'mean-members': 25.0, 'data-points': {'DEMO_DATA__cluster_0': 32, 'DEMO_DATA__cluster_1': 18, 'DEMO_DATA__cluster_2': 33, 'DEMO_DATA__cluster_DEFAULT': 17}, 'argminMetric': 0.2175903576157441}
# True

# %%
import matplotlib.pyplot as plt  # Not Required for Inference, but I am planning to plot few things here.
# %matplotlib
# Out:
# Using matplotlib backend: MacOSX

# %%
preds = []
for i in range(len(df)):
    info = dict(df.loc[i])
    pred, _ = clusterTree.getClusterID(info) 
    preds.append(pred)
df['Predicted_Cluster'] = preds

# %%
df['Predicted_Cluster'].value_counts()
# Out:
# demo_data__cluster_2          33
# demo_data__cluster_0          32
# demo_data__cluster_1          18
# demo_data__cluster_default    17
# Name: Predicted_Cluster, dtype: int64

# %%
colorsByClusters = {'demo_data__cluster_0':0, 'demo_data__cluster_1': 1, 'demo_data__cluster_2':2,
                    'demo_data__cluster_3':3, 'demo_data__cluster_default':4}

df['Color'] = df['Predicted_Cluster'].apply(lambda x: colorsByClusters.get(x))

df.plot.scatter(x="avgspend", y ="people", c='Color', colormap='viridis', s = 50)

# %%
df.plot.scatter(x="people", y ="avgspend", c='Color', colormap='viridis', s = 50)

# %% [markdown]
# ## Test - 2

# %% [markdown]
# **Test of pruning on demo data with min_y = 20[soft bound, hard bound = (20 - 20*0.1)].
# Mechanism used here, is "MergingCentroids" and through this process we are also looking for "balanced" distribution of data points among the clusters without compromising the qulaity of the clusters.**

# %%
df = pd.read_csv('ToDemotestData.csv', delimiter=';')
df.drop(columns='Unnamed: 0', inplace=True)

# %%
df.columns = ['people', 'avgspend']
defaultValues = {'people': 2.0, 'avgspend': 35.0}

# %%
clusterTree = __getClusterTreeFromData(df, categoricalAttributes = None, mergingCentroidsVsconqueringNodes=True,
                                       balancedPrune=True, min_y=20, min_split_fraction=0.05,
                                       conquerDataColumns=None,
                                       prefixString='DEMO_DATA_', defaultValues=defaultValues, prevVer=0.0)

attributes, clusters = getAttributesAndClusters(clusterTree)
writePickleFile(path='./DEMO_DATA_ClusterTree_MC_BlP.pickle', data=clusterTree)

# %%
preds = []
for i in range(len(df)):
    info = dict(df.loc[i])
    pred, _ = clusterTree.getClusterID(info) 
    preds.append(pred)
df['Predicted_Cluster'] = preds

# %%
df['Predicted_Cluster'].value_counts()

# %%
colorsByClusters = {'demo_data__cluster_0':0, 'demo_data__cluster_1': 1, 'demo_data__cluster_2':2,
                    'demo_data__cluster_3':3, 'demo_data__cluster_default':4}

df['Color'] = df['Predicted_Cluster'].apply(lambda x: colorsByClusters.get(x))
df.plot.scatter(x="avgspend", y ="people", c='Color', colormap='viridis', s = 50)

# %%
df.plot.scatter(x="people", y ="avgspend", c='Color', colormap='viridis', s = 50)

# %% [markdown]
# ## Test - 3

# %% [markdown]
# **Test of pruning on demo data with min_y = 20[soft bound, hard bound = (20 - 20*0.1)].
# Mechanism used here, is "ConqueringNodes" with reusing the original data.**

# %%
df = pd.read_csv('ToDemotestData.csv', delimiter=';')
df.drop(columns='Unnamed: 0', inplace=True)

# %%
df.columns = ['people', 'avgspend']
defaultValues = {'people': 2.0, 'avgspend': 35.0}

# %%
clusterTree = __getClusterTreeFromData(df, categoricalAttributes = None, mergingCentroidsVsconqueringNodes=False,
                                       balancedPrune=False, min_y=20, min_split_fraction=0.05,
                                       conquerDataColumns=None,
                                       prefixString='DEMO_DATA_', defaultValues=defaultValues, prevVer=0.0)

attributes, clusters = getAttributesAndClusters(clusterTree)
writePickleFile(path='./DEMO_DATA_ClusterTree_CnqN_D.pickle', data=clusterTree)

# %%
preds = []
for i in range(len(df)):
    info = dict(df.loc[i])
    pred, _ = clusterTree.getClusterID(info) 
    preds.append(pred)
df['Predicted_Cluster'] = preds

# %%
df['Predicted_Cluster'].value_counts()

# %%
colorsByClusters = {'demo_data__cluster_0':0, 'demo_data__cluster_1': 1, 'demo_data__cluster_2':2,
                    'demo_data__cluster_3':3, 'demo_data__cluster_default':4}

df['Color'] = df['Predicted_Cluster'].apply(lambda x: colorsByClusters.get(x))
df.plot.scatter(x="avgspend", y ="people", c='Color', colormap='viridis', s = 50)

# %%
df.plot.scatter(x="people", y ="avgspend", c='Color', colormap='viridis', s = 50)

# %%
from sklearn.datasets import make_blobs
import pandas as pd
X, y = make_blobs(n_samples=500,
                  n_features=2,
                  centers=4,
                  cluster_std=1,
                  center_box=(-10.0, 10.0),
                  shuffle=True,
                  random_state=1)

# %%
set(y)
# Out:
# {0, 1, 2, 3}

# %%
df3=pd.DataFrame(X)

# %%
df3 = df3.round(2)

# %%
df3.columns = ['col1', 'col2']
defaultValues = {'col1': -6.0, 'col2': -2.66}

# %%
clusterTree3 = __getClusterTreeFromData(df3, categoricalAttributes = None, mergingCentroidsVsconqueringNodes=True,
                                       balancedPrune=False, min_y=100, min_split_fraction=0.01,
                                       conquerDataColumns=None,
                                       prefixString='DEMO_DATA2_', defaultValues=defaultValues, prevVer=0.0)

attributes, clusters = getAttributesAndClusters(clusterTree3)
writePickleFile(path='./DEMO_DATA2_ClusterTree.pickle', data=clusterTree3)
# Out:
# 2019-11-26 17:08:24,553 - 4609271232 - INFO - read 500
# 2019-11-26 17:08:24,554 - 4609271232 - INFO - attribute names: [('id', <class 'float'>), ('col2', <class 'float'>), ('col1', <class 'float'>)]
# 2019-11-26 17:08:24,554 - 4609271232 - INFO - This is the starting point!
# 2019-11-26 17:08:24,721 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -12.5
# 2019-11-26 17:08:24,722 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:24,723 - 4609271232 - INFO - Level: 1, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[ 57.    -6.07 -12.5 ]
#  Min :[ 57.    -6.07 -12.5 ]
#
# --------
#
# 2019-11-26 17:08:24,723 - 4609271232 - INFO - At previous level(0), the cut happened on Attribute:col1, Value: -12.5
# 2019-11-26 17:08:24,879 - 4609271232 - INFO - At this level the best cut is found on Attribute: col2, at: -10.94
# 2019-11-26 17:08:24,881 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:24,882 - 4609271232 - INFO - Level: 2, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[408.   -10.94  -7.17]
#  Min :[408.   -10.94  -7.17]
#
# --------
#
# 2019-11-26 17:08:24,883 - 4609271232 - INFO - At previous level(1), the cut happened on Attribute:col2, Value: -10.94
# 2019-11-26 17:08:25,042 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -12.14
# 2019-11-26 17:08:25,044 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:25,045 - 4609271232 - INFO - Level: 3, Datapoints:
# Data: 2
# ['col2', 'col1']
#  Max :[207.    -4.78 -12.14]
#  Min :[201.    -5.73 -12.41]
#
# --------
#
# 2019-11-26 17:08:25,046 - 4609271232 - INFO - At previous level(2), the cut happened on Attribute:col1, Value: -12.14
# 2019-11-26 17:08:25,204 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -12.03
# 2019-11-26 17:08:25,205 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:25,206 - 4609271232 - INFO - Level: 4, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[290.    -5.9  -12.03]
#  Min :[290.    -5.9  -12.03]
#
# --------
#
# 2019-11-26 17:08:25,207 - 4609271232 - INFO - At previous level(3), the cut happened on Attribute:col1, Value: -12.03
# 2019-11-26 17:08:25,359 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -11.95
# 2019-11-26 17:08:25,361 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:25,362 - 4609271232 - INFO - Level: 5, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[212.    -5.36 -11.95]
#  Min :[212.    -5.36 -11.95]
#
# --------
#
# 2019-11-26 17:08:25,363 - 4609271232 - INFO - At previous level(4), the cut happened on Attribute:col1, Value: -11.95
# 2019-11-26 17:08:25,520 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -11.94
# 2019-11-26 17:08:25,521 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:25,522 - 4609271232 - INFO - Level: 6, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[176.    -3.6  -11.94]
#  Min :[176.    -3.6  -11.94]
#
# --------
#
# 2019-11-26 17:08:25,523 - 4609271232 - INFO - At previous level(5), the cut happened on Attribute:col1, Value: -11.94
# 2019-11-26 17:08:25,685 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -11.87
# 2019-11-26 17:08:25,686 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:25,687 - 4609271232 - INFO - Level: 7, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[ 37.    -3.03 -11.87]
#  Min :[ 37.    -3.03 -11.87]
#
# --------
#
# 2019-11-26 17:08:25,687 - 4609271232 - INFO - At previous level(6), the cut happened on Attribute:col1, Value: -11.87
# 2019-11-26 17:08:25,843 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -11.75
# 2019-11-26 17:08:25,844 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:25,845 - 4609271232 - INFO - Level: 8, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[303.    -3.24 -11.75]
#  Min :[303.    -3.24 -11.75]
#
# --------
#
# 2019-11-26 17:08:25,845 - 4609271232 - INFO - At previous level(7), the cut happened on Attribute:col1, Value: -11.75
# 2019-11-26 17:08:25,998 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -11.72
# 2019-11-26 17:08:26,000 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:26,001 - 4609271232 - INFO - Level: 9, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[ 88.    -3.9  -11.72]
#  Min :[ 88.    -3.9  -11.72]
#
# --------
#
# 2019-11-26 17:08:26,001 - 4609271232 - INFO - At previous level(8), the cut happened on Attribute:col1, Value: -11.72
# 2019-11-26 17:08:26,154 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -11.58
# 2019-11-26 17:08:26,155 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:26,156 - 4609271232 - INFO - Level: 10, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[222.    -4.78 -11.58]
#  Min :[222.    -4.78 -11.58]
#
# --------
#
# 2019-11-26 17:08:26,157 - 4609271232 - INFO - At previous level(9), the cut happened on Attribute:col1, Value: -11.58
# 2019-11-26 17:08:26,310 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -11.54
# 2019-11-26 17:08:26,311 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:26,347 - 4609271232 - INFO - Level: 11, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[430.    -4.4  -11.54]
#  Min :[430.    -4.4  -11.54]
#
# --------
#
# 2019-11-26 17:08:26,347 - 4609271232 - INFO - At previous level(10), the cut happened on Attribute:col1, Value: -11.54
# 2019-11-26 17:08:26,509 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -11.44
# 2019-11-26 17:08:26,510 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:26,511 - 4609271232 - INFO - Level: 12, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[103.    -2.72 -11.44]
#  Min :[103.    -2.72 -11.44]
#
# --------
#
# 2019-11-26 17:08:26,512 - 4609271232 - INFO - At previous level(11), the cut happened on Attribute:col1, Value: -11.44
# 2019-11-26 17:08:26,661 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -11.42
# 2019-11-26 17:08:26,663 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:26,664 - 4609271232 - INFO - Level: 13, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[178.    -2.19 -11.42]
#  Min :[178.    -2.19 -11.42]
#
# --------
#
# 2019-11-26 17:08:26,665 - 4609271232 - INFO - At previous level(12), the cut happened on Attribute:col1, Value: -11.42
# 2019-11-26 17:08:26,820 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -11.3
# 2019-11-26 17:08:26,822 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:26,822 - 4609271232 - INFO - Level: 14, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[409.    -3.88 -11.3 ]
#  Min :[409.    -3.88 -11.3 ]
#
# --------
#
# 2019-11-26 17:08:26,823 - 4609271232 - INFO - At previous level(13), the cut happened on Attribute:col1, Value: -11.3
# 2019-11-26 17:08:26,971 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -11.16
# 2019-11-26 17:08:26,972 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:26,974 - 4609271232 - INFO - Level: 15, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[224.    -2.6  -11.16]
#  Min :[224.    -2.6  -11.16]
#
# --------
#
# 2019-11-26 17:08:26,974 - 4609271232 - INFO - At previous level(14), the cut happened on Attribute:col1, Value: -11.16
# 2019-11-26 17:08:27,123 - 4609271232 - INFO - At this level the best cut is found on Attribute: col2, at: -10.67
# 2019-11-26 17:08:27,124 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:27,126 - 4609271232 - INFO - Level: 16, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[  0.   -10.67  -6.92]
#  Min :[  0.   -10.67  -6.92]
#
# --------
# 2019-11-26 17:08:27,126 - 4609271232 - INFO - At previous level(15), the cut happened on Attribute:col2, Value: -10.67
# 2019-11-26 17:08:27,288 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -11.11
# 2019-11-26 17:08:27,290 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:27,290 - 4609271232 - INFO - Level: 17, Datapoints:
# Data: 2
# ['col2', 'col1']
#  Max :[440.    -3.87 -11.11]
#  Min :[ 68.    -3.97 -11.11]
#
# --------
#
# 2019-11-26 17:08:27,292 - 4609271232 - INFO - At previous level(16), the cut happened on Attribute:col1, Value: -11.11
# 2019-11-26 17:08:27,448 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -11.02
# 2019-11-26 17:08:27,449 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:27,451 - 4609271232 - INFO - Level: 18, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[ 21.    -3.16 -11.02]
#  Min :[ 21.    -3.16 -11.02]
#
# --------
#
# 2019-11-26 17:08:27,451 - 4609271232 - INFO - At previous level(17), the cut happened on Attribute:col1, Value: -11.02
# 2019-11-26 17:08:27,601 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.99
# 2019-11-26 17:08:27,602 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:27,603 - 4609271232 - INFO - Level: 19, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[393.    -4.06 -10.99]
#  Min :[393.    -4.06 -10.99]
#
# --------
#
# 2019-11-26 17:08:27,603 - 4609271232 - INFO - At previous level(18), the cut happened on Attribute:col1, Value: -10.99
# 2019-11-26 17:08:27,749 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.95
# 2019-11-26 17:08:27,750 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:27,751 - 4609271232 - INFO - Level: 20, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[ 71.    -3.37 -10.95]
#  Min :[ 71.    -3.37 -10.95]
#
# --------
#
# 2019-11-26 17:08:27,752 - 4609271232 - INFO - At previous level(19), the cut happened on Attribute:col1, Value: -10.95
# 2019-11-26 17:08:27,907 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.93
# 2019-11-26 17:08:27,908 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:27,909 - 4609271232 - INFO - Level: 21, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[485.    -4.49 -10.93]
#  Min :[485.    -4.49 -10.93]
#
# --------
#
# 2019-11-26 17:08:27,910 - 4609271232 - INFO - At previous level(20), the cut happened on Attribute:col1, Value: -10.93
# 2019-11-26 17:08:28,077 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.87
# 2019-11-26 17:08:28,078 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:28,079 - 4609271232 - INFO - Level: 22, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[309.    -4.82 -10.87]
#  Min :[309.    -4.82 -10.87]
#
# --------
#
# 2019-11-26 17:08:28,080 - 4609271232 - INFO - At previous level(21), the cut happened on Attribute:col1, Value: -10.87
# 2019-11-26 17:08:28,231 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.85
# 2019-11-26 17:08:28,232 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:28,233 - 4609271232 - INFO - Level: 23, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[269.    -2.95 -10.85]
#  Min :[269.    -2.95 -10.85]
#
# --------
#
# 2019-11-26 17:08:28,234 - 4609271232 - INFO - At previous level(22), the cut happened on Attribute:col1, Value: -10.85
# 2019-11-26 17:08:28,387 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.83
# 2019-11-26 17:08:28,388 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:28,389 - 4609271232 - INFO - Level: 24, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[249.    -4.83 -10.83]
#  Min :[249.    -4.83 -10.83]
#
# --------
#
# 2019-11-26 17:08:28,390 - 4609271232 - INFO - At previous level(23), the cut happened on Attribute:col1, Value: -10.83
# 2019-11-26 17:08:28,535 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.82
# 2019-11-26 17:08:28,536 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:28,538 - 4609271232 - INFO - Level: 25, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[288.    -3.23 -10.82]
#  Min :[288.    -3.23 -10.82]
#
# --------
#
# 2019-11-26 17:08:28,538 - 4609271232 - INFO - At previous level(24), the cut happened on Attribute:col1, Value: -10.82
# 2019-11-26 17:08:28,684 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.8
# 2019-11-26 17:08:28,685 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:28,686 - 4609271232 - INFO - Level: 26, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[395.    -4.24 -10.8 ]
#  Min :[395.    -4.24 -10.8 ]
#
# --------
#
# 2019-11-26 17:08:28,687 - 4609271232 - INFO - At previous level(25), the cut happened on Attribute:col1, Value: -10.8
# 2019-11-26 17:08:28,829 - 4609271232 - INFO - At this level the best cut is found on Attribute: col2, at: -10.46
# 2019-11-26 17:08:28,830 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:28,831 - 4609271232 - INFO - Level: 27, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[399.   -10.46  -7.66]
#  Min :[399.   -10.46  -7.66]
#
# --------
#
# 2019-11-26 17:08:28,832 - 4609271232 - INFO - At previous level(26), the cut happened on Attribute:col2, Value: -10.46
# 2019-11-26 17:08:28,987 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.78
# 2019-11-26 17:08:28,989 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:28,990 - 4609271232 - INFO - Level: 28, Datapoints:
# Data: 2
# ['col2', 'col1']
#  Max :[446.    -2.84 -10.78]
#  Min :[115.    -4.39 -10.78]
#
# --------
#
# 2019-11-26 17:08:28,990 - 4609271232 - INFO - At previous level(27), the cut happened on Attribute:col1, Value: -10.78
# 2019-11-26 17:08:29,143 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.77
# 2019-11-26 17:08:29,144 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:29,145 - 4609271232 - INFO - Level: 29, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[133.    -3.28 -10.77]
#  Min :[133.    -3.28 -10.77]
#
# --------
#
# 2019-11-26 17:08:29,146 - 4609271232 - INFO - At previous level(28), the cut happened on Attribute:col1, Value: -10.77
# 2019-11-26 17:08:29,300 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.72
# 2019-11-26 17:08:29,302 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:29,303 - 4609271232 - INFO - Level: 30, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[384.    -4.82 -10.72]
#  Min :[384.    -4.82 -10.72]
#
# --------
#
# 2019-11-26 17:08:29,304 - 4609271232 - INFO - At previous level(29), the cut happened on Attribute:col1, Value: -10.72
# 2019-11-26 17:08:29,457 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.7
# 2019-11-26 17:08:29,459 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:29,460 - 4609271232 - INFO - Level: 31, Datapoints:
# Data: 2
# ['col2', 'col1']
#  Max :[327.    -2.76 -10.7 ]
#  Min :[120.    -4.49 -10.7 ]
#
# --------
#
# 2019-11-26 17:08:29,461 - 4609271232 - INFO - At previous level(30), the cut happened on Attribute:col1, Value: -10.7
# 2019-11-26 17:08:29,635 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.62
# 2019-11-26 17:08:29,637 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:29,638 - 4609271232 - INFO - Level: 32, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[ 51.    -4.55 -10.62]
#  Min :[ 51.    -4.55 -10.62]
#
# --------
#
# 2019-11-26 17:08:29,639 - 4609271232 - INFO - At previous level(31), the cut happened on Attribute:col1, Value: -10.62
# 2019-11-26 17:08:29,804 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.56
# 2019-11-26 17:08:29,805 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:29,806 - 4609271232 - INFO - Level: 33, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[428.    -3.01 -10.56]
#  Min :[428.    -3.01 -10.56]
#
# --------
#
# 2019-11-26 17:08:29,806 - 4609271232 - INFO - At previous level(32), the cut happened on Attribute:col1, Value: -10.56
# 2019-11-26 17:08:29,961 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.53
# 2019-11-26 17:08:29,962 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:29,963 - 4609271232 - INFO - Level: 34, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[418.    -2.84 -10.53]
#  Min :[418.    -2.84 -10.53]
#
# --------
#
# 2019-11-26 17:08:29,964 - 4609271232 - INFO - At previous level(33), the cut happened on Attribute:col1, Value: -10.53
# 2019-11-26 17:08:30,119 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.48
# 2019-11-26 17:08:30,120 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:30,121 - 4609271232 - INFO - Level: 35, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[ 20.    -3.6  -10.48]
#  Min :[ 20.    -3.6  -10.48]
#
# --------
#
# 2019-11-26 17:08:30,121 - 4609271232 - INFO - At previous level(34), the cut happened on Attribute:col1, Value: -10.48
# 2019-11-26 17:08:30,271 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.47
# 2019-11-26 17:08:30,272 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:30,273 - 4609271232 - INFO - Level: 36, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[225.    -3.48 -10.47]
#  Min :[225.    -3.48 -10.47]
#
# --------
#
# 2019-11-26 17:08:30,275 - 4609271232 - INFO - At previous level(35), the cut happened on Attribute:col1, Value: -10.47
# 2019-11-26 17:08:30,426 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.45
# 2019-11-26 17:08:30,427 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:30,427 - 4609271232 - INFO - Level: 37, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[357.    -4.63 -10.45]
#  Min :[357.    -4.63 -10.45]
#
# --------
#
# 2019-11-26 17:08:30,428 - 4609271232 - INFO - At previous level(36), the cut happened on Attribute:col1, Value: -10.45
# 2019-11-26 17:08:30,576 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.44
# 2019-11-26 17:08:30,578 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:30,579 - 4609271232 - INFO - Level: 38, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[177.    -3.63 -10.44]
#  Min :[177.    -3.63 -10.44]
#
# --------
#
# 2019-11-26 17:08:30,580 - 4609271232 - INFO - At previous level(37), the cut happened on Attribute:col1, Value: -10.44
# 2019-11-26 17:08:30,731 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.42
# 2019-11-26 17:08:30,732 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:30,733 - 4609271232 - INFO - Level: 39, Datapoints:
# Data: 2
# ['col2', 'col1']
#  Max :[457.    -3.87 -10.42]
#  Min :[276.    -4.43 -10.42]
#
# --------
#
# 2019-11-26 17:08:30,733 - 4609271232 - INFO - At previous level(38), the cut happened on Attribute:col1, Value: -10.42
# 2019-11-26 17:08:30,883 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.41
# 2019-11-26 17:08:30,884 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:30,884 - 4609271232 - INFO - Level: 40, Datapoints:
# Data: 2
# ['col2', 'col1']
#  Max :[464.    -2.67 -10.41]
#  Min :[ 28.    -3.5  -10.41]
#
# --------
#
# 2019-11-26 17:08:30,885 - 4609271232 - INFO - At previous level(39), the cut happened on Attribute:col1, Value: -10.41
# 2019-11-26 17:08:31,035 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.38
# 2019-11-26 17:08:31,036 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:31,037 - 4609271232 - INFO - Level: 41, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[210.    -2.5  -10.38]
#  Min :[210.    -2.5  -10.38]
#
# --------
#
# 2019-11-26 17:08:31,038 - 4609271232 - INFO - At previous level(40), the cut happened on Attribute:col1, Value: -10.38
# 2019-11-26 17:08:31,186 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.37
# 2019-11-26 17:08:31,187 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:31,188 - 4609271232 - INFO - Level: 42, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[363.    -4.7  -10.37]
#  Min :[363.    -4.7  -10.37]
#
# --------
#
# 2019-11-26 17:08:31,188 - 4609271232 - INFO - At previous level(41), the cut happened on Attribute:col1, Value: -10.37
# 2019-11-26 17:08:31,336 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.34
# 2019-11-26 17:08:31,337 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:31,338 - 4609271232 - INFO - Level: 43, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[ 56.    -4.95 -10.34]
#  Min :[ 56.    -4.95 -10.34]
#
# --------
#
# 2019-11-26 17:08:31,339 - 4609271232 - INFO - At previous level(42), the cut happened on Attribute:col1, Value: -10.34
# 2019-11-26 17:08:31,485 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.33
# 2019-11-26 17:08:31,486 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:31,487 - 4609271232 - INFO - Level: 44, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[155.    -3.57 -10.33]
#  Min :[155.    -3.57 -10.33]
#
# --------
#
# 2019-11-26 17:08:31,487 - 4609271232 - INFO - At previous level(43), the cut happened on Attribute:col1, Value: -10.33
# 2019-11-26 17:08:31,636 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.28
# 2019-11-26 17:08:31,637 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:31,639 - 4609271232 - INFO - Level: 45, Datapoints:
# Data: 2
# ['col2', 'col1']
#  Max :[258.    -1.9  -10.28]
#  Min :[160.    -2.33 -10.28]
#
# --------
#
# 2019-11-26 17:08:31,639 - 4609271232 - INFO - At previous level(44), the cut happened on Attribute:col1, Value: -10.28
# 2019-11-26 17:08:31,785 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.25
# 2019-11-26 17:08:31,786 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:31,787 - 4609271232 - INFO - Level: 46, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[473.    -2.55 -10.25]
#  Min :[473.    -2.55 -10.25]
#
# --------
#
# 2019-11-26 17:08:31,787 - 4609271232 - INFO - At previous level(45), the cut happened on Attribute:col1, Value: -10.25
# 2019-11-26 17:08:31,935 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.24
# 2019-11-26 17:08:31,937 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:31,938 - 4609271232 - INFO - Level: 47, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[231.    -2.8  -10.24]
#  Min :[231.    -2.8  -10.24]
#
# --------
#
# 2019-11-26 17:08:31,938 - 4609271232 - INFO - At previous level(46), the cut happened on Attribute:col1, Value: -10.24
# 2019-11-26 17:08:32,081 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.23
# 2019-11-26 17:08:32,082 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:32,083 - 4609271232 - INFO - Level: 48, Datapoints:
# Data: 2
# ['col2', 'col1']
#  Max :[447.    -2.34 -10.23]
#  Min :[ 46.    -3.23 -10.23]
#
# --------
#
# 2019-11-26 17:08:32,084 - 4609271232 - INFO - At previous level(47), the cut happened on Attribute:col1, Value: -10.23
# 2019-11-26 17:08:32,233 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.2
# 2019-11-26 17:08:32,234 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:32,235 - 4609271232 - INFO - Level: 49, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[306.    -2.09 -10.2 ]
#  Min :[306.    -2.09 -10.2 ]
#
# --------
# 2019-11-26 17:08:32,235 - 4609271232 - INFO - At previous level(48), the cut happened on Attribute:col1, Value: -10.2
# 2019-11-26 17:08:32,376 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.19
# 2019-11-26 17:08:32,378 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:32,378 - 4609271232 - INFO - Level: 50, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[344.    -3.15 -10.19]
#  Min :[344.    -3.15 -10.19]
#
# --------
#
# 2019-11-26 17:08:32,379 - 4609271232 - INFO - At previous level(49), the cut happened on Attribute:col1, Value: -10.19
# 2019-11-26 17:08:32,521 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.18
# 2019-11-26 17:08:32,522 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:32,523 - 4609271232 - INFO - Level: 51, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[ 85.    -4.01 -10.18]
#  Min :[ 85.    -4.01 -10.18]
#
# --------
#
# 2019-11-26 17:08:32,524 - 4609271232 - INFO - At previous level(50), the cut happened on Attribute:col1, Value: -10.18
# 2019-11-26 17:08:32,663 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.17
# 2019-11-26 17:08:32,665 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:32,666 - 4609271232 - INFO - Level: 52, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[158.    -4.13 -10.17]
#  Min :[158.    -4.13 -10.17]
#
# --------
#
# 2019-11-26 17:08:32,666 - 4609271232 - INFO - At previous level(51), the cut happened on Attribute:col1, Value: -10.17
# 2019-11-26 17:08:32,807 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.13
# 2019-11-26 17:08:32,809 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:32,809 - 4609271232 - INFO - Level: 53, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[488.    -4.75 -10.13]
#  Min :[488.    -4.75 -10.13]
#
# --------
#
# 2019-11-26 17:08:32,810 - 4609271232 - INFO - At previous level(52), the cut happened on Attribute:col1, Value: -10.13
# 2019-11-26 17:08:32,952 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.11
# 2019-11-26 17:08:32,953 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:32,954 - 4609271232 - INFO - Level: 54, Datapoints:
# Data: 2
# ['col2', 'col1']
#  Max :[109.    -3.94 -10.11]
#  Min :[ 55.    -4.13 -10.11]
#
# --------
#
# 2019-11-26 17:08:32,955 - 4609271232 - INFO - At previous level(53), the cut happened on Attribute:col1, Value: -10.11
# 2019-11-26 17:08:33,099 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.1
# 2019-11-26 17:08:33,100 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:33,101 - 4609271232 - INFO - Level: 55, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[161.    -3.32 -10.1 ]
#  Min :[161.    -3.32 -10.1 ]
#
# --------
#
# 2019-11-26 17:08:33,102 - 4609271232 - INFO - At previous level(54), the cut happened on Attribute:col1, Value: -10.1
# 2019-11-26 17:08:33,241 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.08
# 2019-11-26 17:08:33,243 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:33,243 - 4609271232 - INFO - Level: 56, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[ 36.    -4.25 -10.08]
#  Min :[ 36.    -4.25 -10.08]
#
# --------
#
# 2019-11-26 17:08:33,244 - 4609271232 - INFO - At previous level(55), the cut happened on Attribute:col1, Value: -10.08
# 2019-11-26 17:08:33,383 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.07
# 2019-11-26 17:08:33,385 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:33,385 - 4609271232 - INFO - Level: 57, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[361.    -4.06 -10.07]
#  Min :[361.    -4.06 -10.07]
#
# --------
#
# 2019-11-26 17:08:33,386 - 4609271232 - INFO - At previous level(56), the cut happened on Attribute:col1, Value: -10.07
# 2019-11-26 17:08:33,524 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -10.03
# 2019-11-26 17:08:33,525 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:33,526 - 4609271232 - INFO - Level: 58, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[414.    -1.84 -10.03]
#  Min :[414.    -1.84 -10.03]
#
# --------
#
# 2019-11-26 17:08:33,527 - 4609271232 - INFO - At previous level(57), the cut happened on Attribute:col1, Value: -10.03
# 2019-11-26 17:08:33,675 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -4.98
# 2019-11-26 17:08:33,676 - 4609271232 - INFO - At previous level(58), the cut happened on Attribute:col1, Value: -4.98
# 2019-11-26 17:08:33,745 - 4609271232 - INFO - At this level the best cut is found on Attribute: col2, at: -9.98
# 2019-11-26 17:08:33,746 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:33,746 - 4609271232 - INFO - Level: 60, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[330.    -9.98  -6.67]
#  Min :[330.    -9.98  -6.67]
#
# --------
#
# 2019-11-26 17:08:33,747 - 4609271232 - INFO - At previous level(59), the cut happened on Attribute:col2, Value: -9.98
# 2019-11-26 17:08:33,814 - 4609271232 - INFO - At this level the best cut is found on Attribute: col2, at: -9.85
# 2019-11-26 17:08:33,815 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:33,816 - 4609271232 - INFO - Level: 61, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[304.    -9.85  -9.29]
#  Min :[304.    -9.85  -9.29]
#
# --------
#
# 2019-11-26 17:08:33,817 - 4609271232 - INFO - At previous level(60), the cut happened on Attribute:col2, Value: -9.85
# 2019-11-26 17:08:33,882 - 4609271232 - INFO - At this level the best cut is found on Attribute: col2, at: -9.66
# 2019-11-26 17:08:33,883 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:33,884 - 4609271232 - INFO - Level: 62, Datapoints:
# Data: 2
# ['col2', 'col1']
#  Max :[266.    -9.66  -6.32]
#  Min :[73.   -9.66 -7.24]
#
# --------
#
# 2019-11-26 17:08:33,885 - 4609271232 - INFO - At previous level(61), the cut happened on Attribute:col2, Value: -9.66
# 2019-11-26 17:08:33,957 - 4609271232 - INFO - At this level the best cut is found on Attribute: col2, at: -9.64
# 2019-11-26 17:08:33,958 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:33,959 - 4609271232 - INFO - Level: 63, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[367.    -9.64  -7.43]
#  Min :[367.    -9.64  -7.43]
#
# --------
#
# 2019-11-26 17:08:33,959 - 4609271232 - INFO - At previous level(62), the cut happened on Attribute:col2, Value: -9.64
# 2019-11-26 17:08:34,029 - 4609271232 - INFO - At this level the best cut is found on Attribute: col2, at: -9.63
# 2019-11-26 17:08:34,030 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:34,031 - 4609271232 - INFO - Level: 64, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[35.   -9.63 -6.05]
#  Min :[35.   -9.63 -6.05]
#
# --------
#
# 2019-11-26 17:08:34,031 - 4609271232 - INFO - At previous level(63), the cut happened on Attribute:col2, Value: -9.63
# 2019-11-26 17:08:34,097 - 4609271232 - INFO - At this level the best cut is found on Attribute: col2, at: -9.54
# 2019-11-26 17:08:34,099 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:34,099 - 4609271232 - INFO - Level: 65, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[10.   -9.54 -5.15]
#  Min :[10.   -9.54 -5.15]
#
# --------
#
# 2019-11-26 17:08:34,100 - 4609271232 - INFO - At previous level(64), the cut happened on Attribute:col2, Value: -9.54
# 2019-11-26 17:08:34,165 - 4609271232 - INFO - At this level the best cut is found on Attribute: col2, at: -9.49
# 2019-11-26 17:08:34,166 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:34,167 - 4609271232 - INFO - Level: 66, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[372.    -9.49  -7.22]
#  Min :[372.    -9.49  -7.22]
#
# --------
# 2019-11-26 17:08:34,168 - 4609271232 - INFO - At previous level(65), the cut happened on Attribute:col2, Value: -9.49
# 2019-11-26 17:08:34,232 - 4609271232 - INFO - At this level the best cut is found on Attribute: col2, at: -9.37
# 2019-11-26 17:08:34,234 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:34,235 - 4609271232 - INFO - Level: 67, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[183.    -9.37  -9.76]
#  Min :[183.    -9.37  -9.76]
#
# --------
#
# 2019-11-26 17:08:34,236 - 4609271232 - INFO - At previous level(66), the cut happened on Attribute:col2, Value: -9.37
# 2019-11-26 17:08:34,302 - 4609271232 - INFO - At this level the best cut is found on Attribute: col2, at: -9.32
# 2019-11-26 17:08:34,303 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:34,304 - 4609271232 - INFO - Level: 68, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[439.    -9.32  -6.9 ]
#  Min :[439.    -9.32  -6.9 ]
#
# --------
#
# 2019-11-26 17:08:34,305 - 4609271232 - INFO - At previous level(67), the cut happened on Attribute:col2, Value: -9.32
# 2019-11-26 17:08:34,368 - 4609271232 - INFO - At this level the best cut is found on Attribute: col2, at: -9.31
# 2019-11-26 17:08:34,370 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:34,370 - 4609271232 - INFO - Level: 69, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[192.    -9.31  -5.76]
#  Min :[192.    -9.31  -5.76]
#
# --------
#
# 2019-11-26 17:08:34,371 - 4609271232 - INFO - At previous level(68), the cut happened on Attribute:col2, Value: -9.31
# 2019-11-26 17:08:34,435 - 4609271232 - INFO - At this level the best cut is found on Attribute: col2, at: -9.27
# 2019-11-26 17:08:34,437 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:34,438 - 4609271232 - INFO - Level: 70, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[98.   -9.27 -8.96]
#  Min :[98.   -9.27 -8.96]
#
# --------
#
# 2019-11-26 17:08:34,438 - 4609271232 - INFO - At previous level(69), the cut happened on Attribute:col2, Value: -9.27
# 2019-11-26 17:08:34,502 - 4609271232 - INFO - At this level the best cut is found on Attribute: col2, at: -9.21
# 2019-11-26 17:08:34,504 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:34,505 - 4609271232 - INFO - Level: 71, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[302.    -9.21  -5.84]
#  Min :[302.    -9.21  -5.84]
#
# --------
#
# 2019-11-26 17:08:34,505 - 4609271232 - INFO - At previous level(70), the cut happened on Attribute:col2, Value: -9.21
# 2019-11-26 17:08:34,569 - 4609271232 - INFO - At this level the best cut is found on Attribute: col2, at: -9.17
# 2019-11-26 17:08:34,570 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:34,570 - 4609271232 - INFO - Level: 72, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[188.    -9.17  -7.44]
#  Min :[188.    -9.17  -7.44]
#
# --------
#
# 2019-11-26 17:08:34,571 - 4609271232 - INFO - At previous level(71), the cut happened on Attribute:col2, Value: -9.17
# 2019-11-26 17:08:34,635 - 4609271232 - INFO - At this level the best cut is found on Attribute: col2, at: -9.15
# 2019-11-26 17:08:34,637 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:34,638 - 4609271232 - INFO - Level: 73, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[405.    -9.15  -6.67]
#  Min :[405.    -9.15  -6.67]
#
# --------
#
# 2019-11-26 17:08:34,638 - 4609271232 - INFO - At previous level(72), the cut happened on Attribute:col2, Value: -9.15
# 2019-11-26 17:08:34,702 - 4609271232 - INFO - At this level the best cut is found on Attribute: col2, at: -9.13
# 2019-11-26 17:08:34,703 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:34,703 - 4609271232 - INFO - Level: 74, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[267.    -9.13  -7.52]
#  Min :[267.    -9.13  -7.52]
#
# --------
#
# 2019-11-26 17:08:34,704 - 4609271232 - INFO - At previous level(73), the cut happened on Attribute:col2, Value: -9.13
# 2019-11-26 17:08:34,768 - 4609271232 - INFO - At this level the best cut is found on Attribute: col2, at: -9.07
# 2019-11-26 17:08:34,770 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:34,771 - 4609271232 - INFO - Level: 75, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[179.    -9.07  -9.01]
#  Min :[179.    -9.07  -9.01]
#
# --------
#
# 2019-11-26 17:08:34,772 - 4609271232 - INFO - At previous level(74), the cut happened on Attribute:col2, Value: -9.07
# 2019-11-26 17:08:34,835 - 4609271232 - INFO - At this level the best cut is found on Attribute: col2, at: -8.96
# 2019-11-26 17:08:34,836 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:34,837 - 4609271232 - INFO - Level: 76, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[432.    -8.96  -5.44]
#  Min :[432.    -8.96  -5.44]
#
# --------
#
# 2019-11-26 17:08:34,838 - 4609271232 - INFO - At previous level(75), the cut happened on Attribute:col2, Value: -8.96
# 2019-11-26 17:08:34,900 - 4609271232 - INFO - At this level the best cut is found on Attribute: col2, at: -8.93
# 2019-11-26 17:08:34,901 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:34,902 - 4609271232 - INFO - Level: 77, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[248.    -8.93  -5.32]
#  Min :[248.    -8.93  -5.32]
#
# --------
#
# 2019-11-26 17:08:34,902 - 4609271232 - INFO - At previous level(76), the cut happened on Attribute:col2, Value: -8.93
# 2019-11-26 17:08:34,965 - 4609271232 - INFO - At this level the best cut is found on Attribute: col2, at: -8.91
# 2019-11-26 17:08:34,966 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:34,967 - 4609271232 - INFO - Level: 78, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[200.    -8.91  -6.37]
#  Min :[200.    -8.91  -6.37]
#
# --------
#
# 2019-11-26 17:08:34,968 - 4609271232 - INFO - At previous level(77), the cut happened on Attribute:col2, Value: -8.91
# 2019-11-26 17:08:35,029 - 4609271232 - INFO - At this level the best cut is found on Attribute: col2, at: -1.53
# 2019-11-26 17:08:35,031 - 4609271232 - INFO - At previous level(78), the cut happened on Attribute:col2, Value: -1.53
# 2019-11-26 17:08:35,091 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -9.98
# 2019-11-26 17:08:35,092 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:35,093 - 4609271232 - INFO - Level: 80, Datapoints:
# Data: 4
# ['col2', 'col1']
#  Max :[400.    -3.78  -9.98]
#  Min :[113.    -4.65  -9.98]
#
# --------
#
# 2019-11-26 17:08:35,094 - 4609271232 - INFO - At previous level(79), the cut happened on Attribute:col1, Value: -9.98
# 2019-11-26 17:08:35,154 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -9.94
# 2019-11-26 17:08:35,155 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:35,156 - 4609271232 - INFO - Level: 81, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[325.    -3.74  -9.94]
#  Min :[325.    -3.74  -9.94]
#
# --------
#
# 2019-11-26 17:08:35,156 - 4609271232 - INFO - At previous level(80), the cut happened on Attribute:col1, Value: -9.94
# 2019-11-26 17:08:35,216 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -9.9
# 2019-11-26 17:08:35,217 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:35,218 - 4609271232 - INFO - Level: 82, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[162.    -3.03  -9.9 ]
#  Min :[162.    -3.03  -9.9 ]
#
# --------
#
# 2019-11-26 17:08:35,219 - 4609271232 - INFO - At previous level(81), the cut happened on Attribute:col1, Value: -9.9
# 2019-11-26 17:08:35,277 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -9.89
# 2019-11-26 17:08:35,278 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:35,279 - 4609271232 - INFO - Level: 83, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[489.    -5.48  -9.89]
#  Min :[489.    -5.48  -9.89]
#
# --------
# 2019-11-26 17:08:35,280 - 4609271232 - INFO - At previous level(82), the cut happened on Attribute:col1, Value: -9.89
# 2019-11-26 17:08:35,340 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -9.86
# 2019-11-26 17:08:35,341 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:35,342 - 4609271232 - INFO - Level: 84, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[270.    -2.75  -9.86]
#  Min :[270.    -2.75  -9.86]
#
# --------
#
# 2019-11-26 17:08:35,342 - 4609271232 - INFO - At previous level(83), the cut happened on Attribute:col1, Value: -9.86
# 2019-11-26 17:08:35,401 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -9.84
# 2019-11-26 17:08:35,402 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:35,402 - 4609271232 - INFO - Level: 85, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[159.    -4.14  -9.84]
#  Min :[159.    -4.14  -9.84]
#
# --------
#
# 2019-11-26 17:08:35,404 - 4609271232 - INFO - At previous level(84), the cut happened on Attribute:col1, Value: -9.84
# 2019-11-26 17:08:35,463 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -9.72
# 2019-11-26 17:08:35,464 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:35,465 - 4609271232 - INFO - Level: 86, Datapoints:
# Data: 2
# ['col2', 'col1']
#  Max :[353.    -4.69  -9.72]
#  Min :[163.    -4.78  -9.72]
#
# --------
#
# 2019-11-26 17:08:35,466 - 4609271232 - INFO - At previous level(85), the cut happened on Attribute:col1, Value: -9.72
# 2019-11-26 17:08:35,526 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -9.71
# 2019-11-26 17:08:35,527 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:35,527 - 4609271232 - INFO - Level: 87, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[125.    -3.69  -9.71]
#  Min :[125.    -3.69  -9.71]
#
# --------
#
# 2019-11-26 17:08:35,528 - 4609271232 - INFO - At previous level(86), the cut happened on Attribute:col1, Value: -9.71
# 2019-11-26 17:08:35,585 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -9.69
# 2019-11-26 17:08:35,587 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:35,588 - 4609271232 - INFO - Level: 88, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[375.    -6.05  -9.69]
#  Min :[375.    -6.05  -9.69]
#
# --------
#
# 2019-11-26 17:08:35,589 - 4609271232 - INFO - At previous level(87), the cut happened on Attribute:col1, Value: -9.69
# 2019-11-26 17:08:35,646 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -9.63
# 2019-11-26 17:08:35,648 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:35,648 - 4609271232 - INFO - Level: 89, Datapoints:
# Data: 2
# ['col2', 'col1']
#  Max :[181.    -2.72  -9.63]
#  Min :[ 2.   -5.   -9.63]
#
# --------
#
# 2019-11-26 17:08:35,649 - 4609271232 - INFO - At previous level(88), the cut happened on Attribute:col1, Value: -9.63
# 2019-11-26 17:08:35,710 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -9.58
# 2019-11-26 17:08:35,711 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:35,711 - 4609271232 - INFO - Level: 90, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[131.    -3.17  -9.58]
#  Min :[131.    -3.17  -9.58]
#
# --------
#
# 2019-11-26 17:08:35,712 - 4609271232 - INFO - At previous level(89), the cut happened on Attribute:col1, Value: -9.58
# 2019-11-26 17:08:35,770 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -9.57
# 2019-11-26 17:08:35,771 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:35,771 - 4609271232 - INFO - Level: 91, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[263.    -4.56  -9.57]
#  Min :[263.    -4.56  -9.57]
#
# --------
#
# 2019-11-26 17:08:35,772 - 4609271232 - INFO - At previous level(90), the cut happened on Attribute:col1, Value: -9.57
# 2019-11-26 17:08:35,827 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -9.56
# 2019-11-26 17:08:35,828 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:35,829 - 4609271232 - INFO - Level: 92, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[157.    -2.83  -9.56]
#  Min :[157.    -2.83  -9.56]
#
# --------
#
# 2019-11-26 17:08:35,830 - 4609271232 - INFO - At previous level(91), the cut happened on Attribute:col1, Value: -9.56
# 2019-11-26 17:08:35,885 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -9.55
# 2019-11-26 17:08:35,886 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:35,886 - 4609271232 - INFO - Level: 93, Datapoints:
# Data: 4
# ['col2', 'col1']
#  Max :[469.    -2.19  -9.55]
#  Min :[41.   -5.64 -9.55]
#
# --------
#
# 2019-11-26 17:08:35,887 - 4609271232 - INFO - At previous level(92), the cut happened on Attribute:col1, Value: -9.55
# 2019-11-26 17:08:35,942 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -9.54
# 2019-11-26 17:08:35,944 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:35,945 - 4609271232 - INFO - Level: 94, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[410.    -5.13  -9.54]
#  Min :[410.    -5.13  -9.54]
#
# --------
#
# 2019-11-26 17:08:35,946 - 4609271232 - INFO - At previous level(93), the cut happened on Attribute:col1, Value: -9.54
# 2019-11-26 17:08:36,001 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -9.53
# 2019-11-26 17:08:36,002 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:36,003 - 4609271232 - INFO - Level: 95, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[132.    -2.92  -9.53]
#  Min :[132.    -2.92  -9.53]
#
# --------
#
# 2019-11-26 17:08:36,003 - 4609271232 - INFO - At previous level(94), the cut happened on Attribute:col1, Value: -9.53
# 2019-11-26 17:08:36,056 - 4609271232 - INFO - At this level the best cut is found on Attribute: col1, at: -9.51
# 2019-11-26 17:08:36,057 - 4609271232 - INFO - Inadequate data points to create further split on left child!
# 2019-11-26 17:08:36,058 - 4609271232 - INFO - Level: 96, Datapoints:
# Data: 1
# ['col2', 'col1']
#  Max :[494.    -4.63  -9.51]
#  Min :[494.    -4.63  -9.51]
#
# --------
#
# 2019-11-26 17:08:36,059 - 4609271232 - INFO - At previous level(95), the cut happened on Attribute:col1, Value: -9.51
# ...
# 2019-11-26 17:08:43,536 - 4609271232 - INFO - Level: 164, Datapoints:
# Data: 5
# ['col2', 'col1']
#  Max :[ 4.36e+02  6.59e+00 -3.90e-01]
#  Min :[49.    6.2  -2.22]
#
# --------
#
# 2019-11-26 17:08:43,636 - 4609271232 - INFO - Printing MergeList: []
# 2019-11-26 17:08:43,637 - 4609271232 - INFO - Printing Touching Nodes: {}
# 2019-11-26 17:08:43,695 - 4609271232 - INFO - Min_Y: 90.0, Scenario: dict_values([112, 125, 132, 131]),  #Clusters: 4, argminMetric: 0.07478439452419598
# 2019-11-26 17:08:43,718 - 4609271232 - INFO - Min_Y: 90.0, Scenario: dict_values([125, 132, 243]),  #Clusters: 3, argminMetric: 0.11725921727504672
# 2019-11-26 17:08:43,749 - 4609271232 - INFO - Min_Y: 90.0, Scenario: dict_values([125, 375]),  #Clusters: 2, argminMetric: 0.22619332029857422
# 2019-11-26 17:08:43,758 - 4609271232 - INFO - Searching for 'min_y'. Current 'min_y' = 90.0, 'result' =
# {'intra-cluster-distance': 0.10428236942704723, 'inter-cluster-distance': 1.3944396565556254, 'purity': 0.07478442608598267, 'varPurity': 1.1679108664361706, 'mean-members': 125.0, 'data-points': {'DEMO_DATA2__cluster_0': 112, 'DEMO_DATA2__cluster_1': 125, 'DEMO_DATA2__cluster_2': 132, 'DEMO_DATA2__cluster_3': 131}, 'argminMetric': 0.07478442608598267}
# 2019-11-26 17:08:43,854 - 4609271232 - INFO - Printing MergeList: []
# 2019-11-26 17:08:43,855 - 4609271232 - INFO - Printing Touching Nodes: {}
# 2019-11-26 17:08:43,912 - 4609271232 - INFO - Min_Y: 92.0, Scenario: dict_values([112, 125, 132, 131]),  #Clusters: 4, argminMetric: 0.07478439452419598
# 2019-11-26 17:08:43,939 - 4609271232 - INFO - Min_Y: 92.0, Scenario: dict_values([125, 132, 243]),  #Clusters: 3, argminMetric: 0.11725921727504672
# 2019-11-26 17:08:43,970 - 4609271232 - INFO - Min_Y: 92.0, Scenario: dict_values([125, 375]),  #Clusters: 2, argminMetric: 0.22619332029857422
# 2019-11-26 17:08:43,978 - 4609271232 - INFO - Searching for 'min_y'. Current 'min_y' = 92.0, 'result' =
# {'intra-cluster-distance': 0.10428236942704723, 'inter-cluster-distance': 1.3944396565556254, 'purity': 0.07478442608598267, 'varPurity': 1.1679108664361706, 'mean-members': 125.0, 'data-points': {'DEMO_DATA2__cluster_0': 112, 'DEMO_DATA2__cluster_1': 125, 'DEMO_DATA2__cluster_2': 132, 'DEMO_DATA2__cluster_3': 131}, 'argminMetric': 0.07478442608598267}
# 2019-11-26 17:08:44,073 - 4609271232 - INFO - Printing MergeList: []
# 2019-11-26 17:08:44,074 - 4609271232 - INFO - Printing Touching Nodes: {}
# 2019-11-26 17:08:44,132 - 4609271232 - INFO - Min_Y: 93.0, Scenario: dict_values([112, 125, 132, 131]),  #Clusters: 4, argminMetric: 0.07478439452419598
# 2019-11-26 17:08:44,155 - 4609271232 - INFO - Min_Y: 93.0, Scenario: dict_values([125, 132, 243]),  #Clusters: 3, argminMetric: 0.11725921727504672
# 2019-11-26 17:08:44,186 - 4609271232 - INFO - Min_Y: 93.0, Scenario: dict_values([125, 375]),  #Clusters: 2, argminMetric: 0.22619332029857422
# 2019-11-26 17:08:44,195 - 4609271232 - INFO - Searching for 'min_y'. Current 'min_y' = 93.0, 'result' =
# {'intra-cluster-distance': 0.10428236942704723, 'inter-cluster-distance': 1.3944396565556254, 'purity': 0.07478442608598267, 'varPurity': 1.1679108664361706, 'mean-members': 125.0, 'data-points': {'DEMO_DATA2__cluster_0': 112, 'DEMO_DATA2__cluster_1': 125, 'DEMO_DATA2__cluster_2': 132, 'DEMO_DATA2__cluster_3': 131}, 'argminMetric': 0.07478442608598267}
# 2019-11-26 17:08:44,291 - 4609271232 - INFO - Printing MergeList: []
# 2019-11-26 17:08:44,292 - 4609271232 - INFO - Printing Touching Nodes: {}
# 2019-11-26 17:08:44,345 - 4609271232 - INFO - Min_Y: 94.0, Scenario: dict_values([112, 125, 132, 131]),  #Clusters: 4, argminMetric: 0.07478439452419598
# 2019-11-26 17:08:44,369 - 4609271232 - INFO - Min_Y: 94.0, Scenario: dict_values([125, 132, 243]),  #Clusters: 3, argminMetric: 0.11725921727504672
# 2019-11-26 17:08:44,398 - 4609271232 - INFO - Min_Y: 94.0, Scenario: dict_values([125, 375]),  #Clusters: 2, argminMetric: 0.22619332029857422
# 2019-11-26 17:08:44,406 - 4609271232 - INFO - Searching for 'min_y'. Current 'min_y' = 94.0, 'result' =
# {'intra-cluster-distance': 0.10428236942704723, 'inter-cluster-distance': 1.3944396565556254, 'purity': 0.07478442608598267, 'varPurity': 1.1679108664361706, 'mean-members': 125.0, 'data-points': {'DEMO_DATA2__cluster_0': 112, 'DEMO_DATA2__cluster_1': 125, 'DEMO_DATA2__cluster_2': 132, 'DEMO_DATA2__cluster_3': 131}, 'argminMetric': 0.07478442608598267}
# 2019-11-26 17:08:44,501 - 4609271232 - INFO - Printing MergeList: []
# 2019-11-26 17:08:44,501 - 4609271232 - INFO - Printing Touching Nodes: {}
# 2019-11-26 17:08:44,552 - 4609271232 - INFO - Min_Y: 95.0, Scenario: dict_values([112, 125, 132, 131]),  #Clusters: 4, argminMetric: 0.07478439452419598
# 2019-11-26 17:08:44,575 - 4609271232 - INFO - Min_Y: 95.0, Scenario: dict_values([125, 132, 243]),  #Clusters: 3, argminMetric: 0.11725921727504672
# 2019-11-26 17:08:44,604 - 4609271232 - INFO - Min_Y: 95.0, Scenario: dict_values([125, 375]),  #Clusters: 2, argminMetric: 0.22619332029857422
# 2019-11-26 17:08:44,613 - 4609271232 - INFO - Searching for 'min_y'. Current 'min_y' = 95.0, 'result' =
# {'intra-cluster-distance': 0.10428236942704723, 'inter-cluster-distance': 1.3944396565556254, 'purity': 0.07478442608598267, 'varPurity': 1.1679108664361706, 'mean-members': 125.0, 'data-points': {'DEMO_DATA2__cluster_0': 112, 'DEMO_DATA2__cluster_1': 125, 'DEMO_DATA2__cluster_2': 132, 'DEMO_DATA2__cluster_3': 131}, 'argminMetric': 0.07478442608598267}
# 2019-11-26 17:08:44,711 - 4609271232 - INFO - Printing MergeList: []
# 2019-11-26 17:08:44,712 - 4609271232 - INFO - Printing Touching Nodes: {}
# 2019-11-26 17:08:44,763 - 4609271232 - INFO - Min_Y: 96.0, Scenario: dict_values([112, 125, 132, 131]),  #Clusters: 4, argminMetric: 0.07478439452419598
# 2019-11-26 17:08:44,786 - 4609271232 - INFO - Min_Y: 96.0, Scenario: dict_values([125, 132, 243]),  #Clusters: 3, argminMetric: 0.11725921727504672
# 2019-11-26 17:08:44,818 - 4609271232 - INFO - Min_Y: 96.0, Scenario: dict_values([125, 375]),  #Clusters: 2, argminMetric: 0.22619332029857422
# 2019-11-26 17:08:44,827 - 4609271232 - INFO - Searching for 'min_y'. Current 'min_y' = 96.0, 'result' =
# {'intra-cluster-distance': 0.10428236942704723, 'inter-cluster-distance': 1.3944396565556254, 'purity': 0.07478442608598267, 'varPurity': 1.1679108664361706, 'mean-members': 125.0, 'data-points': {'DEMO_DATA2__cluster_0': 112, 'DEMO_DATA2__cluster_1': 125, 'DEMO_DATA2__cluster_2': 132, 'DEMO_DATA2__cluster_3': 131}, 'argminMetric': 0.07478442608598267}
# 2019-11-26 17:08:44,924 - 4609271232 - INFO - Printing MergeList: []
# 2019-11-26 17:08:44,924 - 4609271232 - INFO - Printing Touching Nodes: {}
# 2019-11-26 17:08:44,976 - 4609271232 - INFO - Min_Y: 97.0, Scenario: dict_values([112, 125, 132, 131]),  #Clusters: 4, argminMetric: 0.07478439452419598
# 2019-11-26 17:08:45,000 - 4609271232 - INFO - Min_Y: 97.0, Scenario: dict_values([125, 132, 243]),  #Clusters: 3, argminMetric: 0.11725921727504672
# 2019-11-26 17:08:45,031 - 4609271232 - INFO - Min_Y: 97.0, Scenario: dict_values([125, 375]),  #Clusters: 2, argminMetric: 0.22619332029857422
# 2019-11-26 17:08:45,040 - 4609271232 - INFO - Searching for 'min_y'. Current 'min_y' = 97.0, 'result' =
# {'intra-cluster-distance': 0.10428236942704723, 'inter-cluster-distance': 1.3944396565556254, 'purity': 0.07478442608598267, 'varPurity': 1.1679108664361706, 'mean-members': 125.0, 'data-points': {'DEMO_DATA2__cluster_0': 112, 'DEMO_DATA2__cluster_1': 125, 'DEMO_DATA2__cluster_2': 132, 'DEMO_DATA2__cluster_3': 131}, 'argminMetric': 0.07478442608598267}
# 2019-11-26 17:08:45,133 - 4609271232 - INFO - Printing MergeList: []
# 2019-11-26 17:08:45,134 - 4609271232 - INFO - Printing Touching Nodes: {}
# 2019-11-26 17:08:45,185 - 4609271232 - INFO - Min_Y: 98.0, Scenario: dict_values([112, 125, 132, 131]),  #Clusters: 4, argminMetric: 0.07478439452419598
# 2019-11-26 17:08:45,207 - 4609271232 - INFO - Min_Y: 98.0, Scenario: dict_values([125, 132, 243]),  #Clusters: 3, argminMetric: 0.11725921727504672
# 2019-11-26 17:08:45,237 - 4609271232 - INFO - Min_Y: 98.0, Scenario: dict_values([125, 375]),  #Clusters: 2, argminMetric: 0.22619332029857422
# 2019-11-26 17:08:45,246 - 4609271232 - INFO - Searching for 'min_y'. Current 'min_y' = 98.0, 'result' =
# {'intra-cluster-distance': 0.10428236942704723, 'inter-cluster-distance': 1.3944396565556254, 'purity': 0.07478442608598267, 'varPurity': 1.1679108664361706, 'mean-members': 125.0, 'data-points': {'DEMO_DATA2__cluster_0': 112, 'DEMO_DATA2__cluster_1': 125, 'DEMO_DATA2__cluster_2': 132, 'DEMO_DATA2__cluster_3': 131}, 'argminMetric': 0.07478442608598267}
# 2019-11-26 17:08:45,344 - 4609271232 - INFO - Printing MergeList: []
# 2019-11-26 17:08:45,344 - 4609271232 - INFO - Printing Touching Nodes: {}
# 2019-11-26 17:08:45,397 - 4609271232 - INFO - Min_Y: 99.0, Scenario: dict_values([112, 125, 132, 131]),  #Clusters: 4, argminMetric: 0.07478439452419598
# 2019-11-26 17:08:45,420 - 4609271232 - INFO - Min_Y: 99.0, Scenario: dict_values([125, 132, 243]),  #Clusters: 3, argminMetric: 0.11725921727504672
# 2019-11-26 17:08:45,450 - 4609271232 - INFO - Min_Y: 99.0, Scenario: dict_values([125, 375]),  #Clusters: 2, argminMetric: 0.22619332029857422
# 2019-11-26 17:08:45,459 - 4609271232 - INFO - Searching for 'min_y'. Current 'min_y' = 99.0, 'result' =
# {'intra-cluster-distance': 0.10428236942704723, 'inter-cluster-distance': 1.3944396565556254, 'purity': 0.07478442608598267, 'varPurity': 1.1679108664361706, 'mean-members': 125.0, 'data-points': {'DEMO_DATA2__cluster_0': 112, 'DEMO_DATA2__cluster_1': 125, 'DEMO_DATA2__cluster_2': 132, 'DEMO_DATA2__cluster_3': 131}, 'argminMetric': 0.07478442608598267}
# 2019-11-26 17:08:45,556 - 4609271232 - INFO - Printing MergeList: []
# 2019-11-26 17:08:45,556 - 4609271232 - INFO - Printing Touching Nodes: {}
# 2019-11-26 17:08:45,607 - 4609271232 - INFO - Min_Y: 100.0, Scenario: dict_values([112, 125, 132, 131]),  #Clusters: 4, argminMetric: 0.07478439452419598
# 2019-11-26 17:08:45,630 - 4609271232 - INFO - Min_Y: 100.0, Scenario: dict_values([125, 132, 243]),  #Clusters: 3, argminMetric: 0.11725921727504672
# 2019-11-26 17:08:45,661 - 4609271232 - INFO - Min_Y: 100.0, Scenario: dict_values([125, 375]),  #Clusters: 2, argminMetric: 0.22619332029857422
# 2019-11-26 17:08:45,671 - 4609271232 - INFO - Searching for 'min_y'. Current 'min_y' = 100.0, 'result' =
# {'intra-cluster-distance': 0.10428236942704723, 'inter-cluster-distance': 1.3944396565556254, 'purity': 0.07478442608598267, 'varPurity': 1.1679108664361706, 'mean-members': 125.0, 'data-points': {'DEMO_DATA2__cluster_0': 112, 'DEMO_DATA2__cluster_1': 125, 'DEMO_DATA2__cluster_2': 132, 'DEMO_DATA2__cluster_3': 131}, 'argminMetric': 0.07478442608598267}
# 2019-11-26 17:08:45,671 - 4609271232 - INFO - balancedPrune: False, All argminMetric: {90.0: 0.07478442608598267, 92.0: 0.07478442608598267, 93.0: 0.07478442608598267, 94.0: 0.07478442608598267, 95.0: 0.07478442608598267, 96.0: 0.07478442608598267, 97.0: 0.07478442608598267, 98.0: 0.07478442608598267, 99.0: 0.07478442608598267, 100.0: 0.07478442608598267}
# 2019-11-26 17:08:45,672 - 4609271232 - INFO - All intermediate stats, generated during grid search: {90.0: {'intra-cluster-distance': 0.10428236942704723, 'inter-cluster-distance': 1.3944396565556254, 'purity': 0.07478442608598267, 'varPurity': 1.1679108664361706, 'mean-members': 125.0, 'data-points': {'DEMO_DATA2__cluster_0': 112, 'DEMO_DATA2__cluster_1': 125, 'DEMO_DATA2__cluster_2': 132, 'DEMO_DATA2__cluster_3': 131}, 'argminMetric': 0.07478442608598267}, 92.0: {'intra-cluster-distance': 0.10428236942704723, 'inter-cluster-distance': 1.3944396565556254, 'purity': 0.07478442608598267, 'varPurity': 1.1679108664361706, 'mean-members': 125.0, 'data-points': {'DEMO_DATA2__cluster_0': 112, 'DEMO_DATA2__cluster_1': 125, 'DEMO_DATA2__cluster_2': 132, 'DEMO_DATA2__cluster_3': 131}, 'argminMetric': 0.07478442608598267}, 93.0: {'intra-cluster-distance': 0.10428236942704723, 'inter-cluster-distance': 1.3944396565556254, 'purity': 0.07478442608598267, 'varPurity': 1.1679108664361706, 'mean-members': 125.0, 'data-points': {'DEMO_DATA2__cluster_0': 112, 'DEMO_DATA2__cluster_1': 125, 'DEMO_DATA2__cluster_2': 132, 'DEMO_DATA2__cluster_3': 131}, 'argminMetric': 0.07478442608598267}, 94.0: {'intra-cluster-distance': 0.10428236942704723, 'inter-cluster-distance': 1.3944396565556254, 'purity': 0.07478442608598267, 'varPurity': 1.1679108664361706, 'mean-members': 125.0, 'data-points': {'DEMO_DATA2__cluster_0': 112, 'DEMO_DATA2__cluster_1': 125, 'DEMO_DATA2__cluster_2': 132, 'DEMO_DATA2__cluster_3': 131}, 'argminMetric': 0.07478442608598267}, 95.0: {'intra-cluster-distance': 0.10428236942704723, 'inter-cluster-distance': 1.3944396565556254, 'purity': 0.07478442608598267, 'varPurity': 1.1679108664361706, 'mean-members': 125.0, 'data-points': {'DEMO_DATA2__cluster_0': 112, 'DEMO_DATA2__cluster_1': 125, 'DEMO_DATA2__cluster_2': 132, 'DEMO_DATA2__cluster_3': 131}, 'argminMetric': 0.07478442608598267}, 96.0: {'intra-cluster-distance': 0.10428236942704723, 'inter-cluster-distance': 1.3944396565556254, 'purity': 0.07478442608598267, 'varPurity': 1.1679108664361706, 'mean-members': 125.0, 'data-points': {'DEMO_DATA2__cluster_0': 112, 'DEMO_DATA2__cluster_1': 125, 'DEMO_DATA2__cluster_2': 132, 'DEMO_DATA2__cluster_3': 131}, 'argminMetric': 0.07478442608598267}, 97.0: {'intra-cluster-distance': 0.10428236942704723, 'inter-cluster-distance': 1.3944396565556254, 'purity': 0.07478442608598267, 'varPurity': 1.1679108664361706, 'mean-members': 125.0, 'data-points': {'DEMO_DATA2__cluster_0': 112, 'DEMO_DATA2__cluster_1': 125, 'DEMO_DATA2__cluster_2': 132, 'DEMO_DATA2__cluster_3': 131}, 'argminMetric': 0.07478442608598267}, 98.0: {'intra-cluster-distance': 0.10428236942704723, 'inter-cluster-distance': 1.3944396565556254, 'purity': 0.07478442608598267, 'varPurity': 1.1679108664361706, 'mean-members': 125.0, 'data-points': {'DEMO_DATA2__cluster_0': 112, 'DEMO_DATA2__cluster_1': 125, 'DEMO_DATA2__cluster_2': 132, 'DEMO_DATA2__cluster_3': 131}, 'argminMetric': 0.07478442608598267}, 99.0: {'intra-cluster-distance': 0.10428236942704723, 'inter-cluster-distance': 1.3944396565556254, 'purity': 0.07478442608598267, 'varPurity': 1.1679108664361706, 'mean-members': 125.0, 'data-points': {'DEMO_DATA2__cluster_0': 112, 'DEMO_DATA2__cluster_1': 125, 'DEMO_DATA2__cluster_2': 132, 'DEMO_DATA2__cluster_3': 131}, 'argminMetric': 0.07478442608598267}, 100.0: {'intra-cluster-distance': 0.10428236942704723, 'inter-cluster-distance': 1.3944396565556254, 'purity': 0.07478442608598267, 'varPurity': 1.1679108664361706, 'mean-members': 125.0, 'data-points': {'DEMO_DATA2__cluster_0': 112, 'DEMO_DATA2__cluster_1': 125, 'DEMO_DATA2__cluster_2': 132, 'DEMO_DATA2__cluster_3': 131}, 'argminMetric': 0.07478442608598267}}
# 2019-11-26 17:08:45,768 - 4609271232 - INFO - Printing MergeList: []
# 2019-11-26 17:08:45,769 - 4609271232 - INFO - Printing Touching Nodes: {}
# 2019-11-26 17:08:45,821 - 4609271232 - INFO - Min_Y: 90.0, Scenario: dict_values([112, 125, 132, 131]),  #Clusters: 4, argminMetric: 0.07478439452419598
# 2019-11-26 17:08:45,845 - 4609271232 - INFO - Min_Y: 90.0, Scenario: dict_values([125, 132, 243]),  #Clusters: 3, argminMetric: 0.11725921727504672
# 2019-11-26 17:08:45,876 - 4609271232 - INFO - Min_Y: 90.0, Scenario: dict_values([125, 375]),  #Clusters: 2, argminMetric: 0.22619332029857422
# 2019-11-26 17:08:45,896 - 4609271232 - INFO - Search Mode: False.            Note: The underlying Tree structure got modified in the process of pruning to make the search space optimized!            'min_y' = 90.0, 'result' =
# {'intra-cluster-distance': 0.10428232550005959, 'inter-cluster-distance': 1.3944396565544452, 'purity': 0.0747843945845124, 'varPurity': 1.1679107900759065, 'mean-members': 125.0, 'data-points': {'DEMO_DATA2__cluster_0': 112, 'DEMO_DATA2__cluster_1': 125, 'DEMO_DATA2__cluster_2': 132, 'DEMO_DATA2__cluster_3': 131}, 'argminMetric': 0.0747843945845124}
# True

# %%
clusterTree3.attributeToDataType
# Out:
# {'col1': (int, float), 'col2': (int, float)}

# %%
clusterTree3.defaultVals
# Out:
# {'col1': -6.0, 'col2': -2.66}

# %%
print(attributes)
clusters
# Out:
# {'col2', 'col1'}
# {'demo_data2__cluster_0',
#  'demo_data2__cluster_1',
#  'demo_data2__cluster_2',
#  'demo_data2__cluster_3'}

# %%
preds2 = []
for i in range(len(df3)):
    info = dict(df3.loc[i])
    pred2, _ = clusterTree3.getClusterID(info) 
    preds2.append(pred2)
df3['Predicted_Cluster'] = preds2

# %%
df3['Predicted_Cluster'].value_counts()
# Out:
# demo_data2__cluster_2    132
# demo_data2__cluster_3    131
# demo_data2__cluster_1    125
# demo_data2__cluster_0    112
# Name: Predicted_Cluster, dtype: int64

# %%
colorsByClusters = {'demo_data2__cluster_0':0, 'demo_data2__cluster_1': 1, 'demo_data2__cluster_2':2,
                    'demo_data2__cluster_3':3, 'demo_data2__cluster_default':4}

df3['Color'] = df3['Predicted_Cluster'].apply(lambda x: colorsByClusters.get(x))

df3.plot.scatter(x="col2", y ="col1", c='Color', colormap='viridis', s = 50)

# %%
df3.plot.scatter(x="col1", y ="col2", c='Color', colormap='viridis', s = 50)
